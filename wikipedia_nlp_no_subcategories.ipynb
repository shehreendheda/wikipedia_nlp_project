# %%
import pymongo
import pickle
import redis
import matplotlib.pyplot as plt
# %matplotlib inline
import wikipedia
import pandas as pd
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')
import pprint
pp = pprint.PrettyPrinter(indent=1)

rcparams = {'legend.fontsize': 'large',
          'figure.figsize': (10,8),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large',
         'axes.labelweight' : 'bold',
         'axes.titleweight' : 'bold'}
plt.rcParams.update(rcparams)


from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit

from wikipedia_helper import *

# %% [markdown]
# ## Downloading articles

# %%
mgclient = pymongo.MongoClient('54.202.56.110')
wikipedia_db = mgclient.database_names()
article_collector = mgclient.wikipedia_db.article_collector
if mgclient.wikipedia_db.article_collector.count() != 0:
    mgclient.wikipedia_db.drop_collection(article_collector)
    test_collector = mgclient.wikipedia_db.article_collector

wiki_categories = [line.rstrip('\n') for line in open('list_of_categories.txt')]
wiki_categories = [line.split(':')[2] for line in wiki_categories]

pageid_title_df, subcat_dict, uncollected_articles = get_article_category_pageid_titles(wiki_categories,article_collector)

r = redis.StrictRedis('54.202.56.110')
subcat_dict = pickle.dumps(subcat_dict)
pageid_title_df = pickle.dumps(pageid_title_df)
uncollected_articles = pickle.dumps(uncollected_articles)
r.set('subcat_dict',subcat_dict)
r.set('pageid_title_df',pageid_title_df)
r.set('uncollected_articles',uncollected_articles)
# Out:
# Collecting articles for Machine_learning
# 100%|████████████████████████████████████████████████████████████████████████████████| 195/195 [05:51<00:00,  1.76s/it]
# number of articles found: 195
# number of articles stored: 195
#
#
# Collecting articles for Business_intelligence
# 100%|████████████████████████████████████████████████████████████████████████████████| 175/175 [05:08<00:00,  1.74s/it]
# number of articles found: 175
# number of articles stored: 370
#
#
# Collecting articles for Artificial_intelligence
# 100%|████████████████████████████████████████████████████████████████████████████████| 304/304 [09:03<00:00,  1.68s/it]
# number of articles found: 304
# number of articles stored: 671
#
#
# Collecting articles for Computational_statistics
# 100%|██████████████████████████████████████████████████████████████████████████████████| 41/41 [01:16<00:00,  1.84s/it]
# number of articles found: 41
# number of articles stored: 712
#
#
# Collecting articles for Robotics
# 100%|████████████████████████████████████████████████████████████████████████████████| 109/109 [03:11<00:00,  1.90s/it]
# number of articles found: 109
# number of articles stored: 820
#
#
# Collecting articles for Data_analysis
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:49<00:00,  1.70s/it]
# number of articles found: 29
# number of articles stored: 849
#
#
# Collecting articles for Bioinformatics
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [14:46<00:00,  1.83s/it]
# number of articles found: 500
# number of articles stored: 1343
#
#
# Collecting articles for Operations_research
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [05:58<00:00,  1.71s/it]
# number of articles found: 200
# number of articles stored: 1542
#
#
# Collecting articles for Information_science
# 100%|████████████████████████████████████████████████████████████████████████████████| 215/215 [06:15<00:00,  1.69s/it]
# number of articles found: 215
# number of articles stored: 1756
#
#
# Collecting articles for Aerospace_engineering
# 100%|████████████████████████████████████████████████████████████████████████████████| 176/176 [05:01<00:00,  1.68s/it]
# number of articles found: 176
# number of articles stored: 1932
#
#
# Collecting articles for Biological_engineering
# 100%|██████████████████████████████████████████████████████████████████████████████████| 73/73 [02:10<00:00,  1.87s/it]
# number of articles found: 73
# number of articles stored: 2005
#
#
# Collecting articles for Electrical_engineering
# 100%|████████████████████████████████████████████████████████████████████████████████| 231/231 [06:51<00:00,  1.73s/it]
# number of articles found: 231
# number of articles stored: 2236
#
#
# Collecting articles for Mechanical_engineering
# 100%|████████████████████████████████████████████████████████████████████████████████| 244/244 [07:11<00:00,  1.85s/it]
# number of articles found: 244
# number of articles stored: 2480
#
#
# Collecting articles for Software_engineering
# 100%|██████████████████████████████████████████████████████████████████████████████████| 54/54 [01:36<00:00,  1.81s/it]
# number of articles found: 54
# number of articles stored: 2534
#
#
# Collecting articles for Systems_engineering
# 100%|████████████████████████████████████████████████████████████████████████████████| 217/217 [06:19<00:00,  1.60s/it]
# number of articles found: 217
# number of articles stored: 2749
#
# Machine_learning has 195 articles.
# Business_intelligence has 175 articles.
# Artificial_intelligence has 304 articles.
# Computational_statistics has 41 articles.
# Robotics has 109 articles.
# Data_analysis has 29 articles.
# Bioinformatics has 500 articles.
# Operations_research has 200 articles.
# Information_science has 215 articles.
# Aerospace_engineering has 176 articles.
# Biological_engineering has 73 articles.
# Electrical_engineering has 231 articles.
# Mechanical_engineering has 244 articles.
# Software_engineering has 54 articles.
# Systems_engineering has 217 articles.
# The total number of unique articles found is 2763.
# The total number of articles stored is 2749.
# True

# %% [markdown]
# ## Training a model

# %%
print("\nRetrieving article texts...")

curs_test = mgclient.wikipedia_db.article_collector.find()

article_contents_df = get_clean_mongo_dataframe(load_wiki_docs(curs_test,mgclient.wikipedia_db.article_collector.count()))

pipe = Pipeline([('tfidf',TfidfVectorizer(stop_words = 'english')),
               ('svd', TruncatedSVD(random_state=12)),
               ('knn', KNeighborsClassifier())])

params = {
            'tfidf__min_df' : [1,2,3],
            'svd__n_components' : [10,50,100],
            'knn__n_neighbors' : range(3,20,2)
}

print("\nFitting the model now...")

gs_pipe = GridSearchCV(pipe, param_grid=params,cv=StratifiedShuffleSplit(random_state=12))
gs_pipe.fit(article_contents_df['clean_text'],article_contents_df['category'])

r = redis.StrictRedis('54.202.56.110')
all_models = pickle.dumps(gs_pipe)
best_models = pickle.dumps(gs_pipe.best_estimator_)
lsa_vectorizer = pickle.dumps(gs_pipe.best_estimator_.steps[0][1])
fit_svd = pickle.dumps(gs_pipe.best_estimator_.steps[1][1])
knn_model = pickle.dumps(gs_pipe.best_estimator_.steps[2][1])
article_df = pickle.dumps(article_contents_df)
r.set('all_models',all_models)
r.set('best_model',best_models)
r.set('vectorizer',lsa_vectorizer)
r.set('fit_svd',fit_svd)
r.set('knn_model',knn_model)
r.set('article_data_df',article_df)

print("\nThe model is ready to make predictions!")
# Out:
# Retrieving article texts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 2749/2749 [01:49<00:00, 25.14it/s]
# Fitting the model now...
#
# The model is ready to make predictions!

# %%
gs_pipe_df = pd.DataFrame(gs_pipe.cv_results_)
gs_pipe_df.sort_values('rank_test_score').T
# Out:
#                                                                         68  \
# mean_fit_time                                                       3.8858
# mean_score_time                                                   0.364253
# mean_test_score                                                       0.75
# mean_train_score                                                  0.775291
# param_knn__n_neighbors                                                  17
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 17, 'svd__n_components': ...
# rank_test_score                                                          1
# split0_test_score                                                 0.757463
# split0_train_score                                                0.776206
# split1_test_score                                                 0.776119
# split1_train_score                                                0.771215
# split2_test_score                                                     0.75
# split2_train_score                                                 0.77579
# split3_test_score                                                 0.757463
# split3_train_score                                                0.778286
# split4_test_score                                                 0.723881
# split4_train_score                                                0.782862
# split5_test_score                                                 0.753731
# split5_train_score                                                0.771631
# split6_test_score                                                 0.742537
# split6_train_score                                                0.771215
# split7_test_score                                                 0.776119
# split7_train_score                                                0.773295
# split8_test_score                                                 0.742537
# split8_train_score                                                0.780366
# split9_test_score                                                 0.720149
# split9_train_score                                                0.772047
# std_fit_time                                                     0.0558656
# std_score_time                                                   0.0187605
# std_test_score                                                   0.0178169
# std_train_score                                                 0.00392781
#
#                                                                         49  \
# mean_fit_time                                                        4.111
# mean_score_time                                                   0.359408
# mean_test_score                                                   0.749627
# mean_train_score                                                  0.784526
# param_knn__n_neighbors                                                  13
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 13, 'svd__n_components': ...
# rank_test_score                                                          2
# split0_test_score                                                 0.753731
# split0_train_score                                                0.787438
# split1_test_score                                                 0.783582
# split1_train_score                                                0.781614
# split2_test_score                                                 0.757463
# split2_train_score                                                0.787022
# split3_test_score                                                 0.746269
# split3_train_score                                                 0.78619
# split4_test_score                                                 0.716418
# split4_train_score                                                0.790765
# split5_test_score                                                 0.735075
# split5_train_score                                                0.781198
# split6_test_score                                                 0.742537
# split6_train_score                                                 0.77995
# split7_test_score                                                 0.776119
# split7_train_score                                                0.776206
# split8_test_score                                                 0.742537
# split8_train_score                                                0.787854
# split9_test_score                                                 0.742537
# split9_train_score                                                0.787022
# std_fit_time                                                      0.179191
# std_score_time                                                   0.0357588
# std_test_score                                                   0.0184654
# std_train_score                                                 0.00428271
#
#                                                                         58  \
# mean_fit_time                                                      4.39004
# mean_score_time                                                   0.392376
# mean_test_score                                                   0.749254
# mean_train_score                                                  0.780075
# param_knn__n_neighbors                                                  15
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 15, 'svd__n_components': ...
# rank_test_score                                                          3
# split0_test_score                                                 0.768657
# split0_train_score                                                0.781198
# split1_test_score                                                 0.768657
# split1_train_score                                                0.772463
# split2_test_score                                                 0.738806
# split2_train_score                                                0.783278
# split3_test_score                                                 0.757463
# split3_train_score                                                0.787854
# split4_test_score                                                 0.735075
# split4_train_score                                                0.783278
# split5_test_score                                                 0.727612
# split5_train_score                                                0.778286
# split6_test_score                                                 0.746269
# split6_train_score                                                0.775374
# split7_test_score                                                 0.764925
# split7_train_score                                                0.772879
# split8_test_score                                                     0.75
# split8_train_score                                                0.783278
# split9_test_score                                                 0.735075
# split9_train_score                                                0.782862
# std_fit_time                                                      0.155991
# std_score_time                                                   0.0406433
# std_test_score                                                   0.0143354
# std_train_score                                                 0.00485122
#
#                                                                         40  \
# mean_fit_time                                                      4.17338
# mean_score_time                                                   0.361505
# mean_test_score                                                   0.746642
# mean_train_score                                                  0.788062
# param_knn__n_neighbors                                                  11
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 11, 'svd__n_components': ...
# rank_test_score                                                          4
# split0_test_score                                                     0.75
# split0_train_score                                                0.790765
# split1_test_score                                                 0.791045
# split1_train_score                                                0.786606
# split2_test_score                                                 0.738806
# split2_train_score                                                0.789933
# split3_test_score                                                 0.742537
# split3_train_score                                                0.787022
# split4_test_score                                                 0.712687
# split4_train_score                                                0.792429
# split5_test_score                                                 0.738806
# split5_train_score                                                0.783694
# split6_test_score                                                 0.746269
# split6_train_score                                                0.783694
# split7_test_score                                                 0.746269
# split7_train_score                                                0.782862
# split8_test_score                                                 0.746269
# split8_train_score                                                0.797005
# split9_test_score                                                 0.753731
# split9_train_score                                                0.786606
# std_fit_time                                                     0.0633207
# std_score_time                                                   0.0230307
# std_test_score                                                   0.0182378
# std_train_score                                                 0.00424721
#
#                                                                         59  \
# mean_fit_time                                                      4.11145
# mean_score_time                                                   0.380627
# mean_test_score                                                   0.746269
# mean_train_score                                                  0.780865
# param_knn__n_neighbors                                                  15
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 15, 'svd__n_components': ...
# rank_test_score                                                          5
# split0_test_score                                                 0.753731
# split0_train_score                                                 0.77995
# split1_test_score                                                 0.776119
# split1_train_score                                                0.774958
# split2_test_score                                                     0.75
# split2_train_score                                                 0.78827
# split3_test_score                                                 0.757463
# split3_train_score                                                0.785358
# split4_test_score                                                 0.723881
# split4_train_score                                                0.781614
# split5_test_score                                                 0.731343
# split5_train_score                                                0.778702
# split6_test_score                                                 0.738806
# split6_train_score                                                0.778702
# split7_test_score                                                 0.776119
# split7_train_score                                                0.779534
# split8_test_score                                                 0.731343
# split8_train_score                                                 0.77995
# split9_test_score                                                 0.723881
# split9_train_score                                                0.781614
# std_fit_time                                                      0.260073
# std_score_time                                                   0.0488506
# std_test_score                                                   0.0186567
# std_train_score                                                 0.00351885
#
#                                                                         76  \
# mean_fit_time                                                       5.5421
# mean_score_time                                                   0.468525
# mean_test_score                                                   0.744403
# mean_train_score                                                   0.77292
# param_knn__n_neighbors                                                  19
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 19, 'svd__n_components': ...
# rank_test_score                                                          6
# split0_test_score                                                     0.75
# split0_train_score                                                0.777454
# split1_test_score                                                 0.779851
# split1_train_score                                                0.766223
# split2_test_score                                                 0.746269
# split2_train_score                                                 0.77579
# split3_test_score                                                 0.764925
# split3_train_score                                                 0.77579
# split4_test_score                                                 0.686567
# split4_train_score                                                0.778702
# split5_test_score                                                 0.723881
# split5_train_score                                                0.774126
# split6_test_score                                                 0.757463
# split6_train_score                                                0.771631
# split7_test_score                                                 0.761194
# split7_train_score                                                0.769135
# split8_test_score                                                 0.746269
# split8_train_score                                                0.771215
# split9_test_score                                                 0.727612
# split9_train_score                                                0.769135
# std_fit_time                                                      0.835175
# std_score_time                                                    0.103602
# std_test_score                                                   0.0249331
# std_train_score                                                 0.00387302
#
#                                                                         31  \
# mean_fit_time                                                      4.13829
# mean_score_time                                                   0.357803
# mean_test_score                                                    0.74403
# mean_train_score                                                  0.795882
# param_knn__n_neighbors                                                   9
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 9, 'svd__n_components': 5...
# rank_test_score                                                          7
# split0_test_score                                                 0.746269
# split0_train_score                                                0.799085
# split1_test_score                                                 0.787313
# split1_train_score                                                0.793677
# split2_test_score                                                 0.738806
# split2_train_score                                                0.795757
# split3_test_score                                                 0.757463
# split3_train_score                                                0.804077
# split4_test_score                                                 0.708955
# split4_train_score                                                0.795757
# split5_test_score                                                 0.720149
# split5_train_score                                                0.799085
# split6_test_score                                                     0.75
# split6_train_score                                                0.792845
# split7_test_score                                                 0.757463
# split7_train_score                                                0.789933
# split8_test_score                                                 0.731343
# split8_train_score                                                0.792429
# split9_test_score                                                 0.742537
# split9_train_score                                                0.796173
# std_fit_time                                                     0.0601175
# std_score_time                                                   0.0279698
# std_test_score                                                   0.0206543
# std_train_score                                                 0.00386229
#
#                                                                         41  \
# mean_fit_time                                                      3.92299
# mean_score_time                                                   0.354906
# mean_test_score                                                   0.743657
# mean_train_score                                                  0.788727
# param_knn__n_neighbors                                                  11
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 11, 'svd__n_components': ...
# rank_test_score                                                          8
# split0_test_score                                                 0.735075
# split0_train_score                                                0.794093
# split1_test_score                                                 0.768657
# split1_train_score                                                0.786606
# split2_test_score                                                 0.742537
# split2_train_score                                                0.794509
# split3_test_score                                                 0.768657
# split3_train_score                                                0.792013
# split4_test_score                                                 0.712687
# split4_train_score                                                0.787022
# split5_test_score                                                 0.746269
# split5_train_score                                                0.787438
# split6_test_score                                                     0.75
# split6_train_score                                                 0.77787
# split7_test_score                                                 0.761194
# split7_train_score                                                0.787022
# split8_test_score                                                 0.723881
# split8_train_score                                                0.794509
# split9_test_score                                                 0.727612
# split9_train_score                                                 0.78619
# std_fit_time                                                     0.0581978
# std_score_time                                                    0.021181
# std_test_score                                                   0.0181306
# std_train_score                                                 0.00492696
#
#                                                                         50  \
# mean_fit_time                                                       3.8134
# mean_score_time                                                   0.350713
# mean_test_score                                                   0.743284
# mean_train_score                                                  0.783361
# param_knn__n_neighbors                                                  13
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 13, 'svd__n_components': ...
# rank_test_score                                                          9
# split0_test_score                                                 0.753731
# split0_train_score                                                0.790349
# split1_test_score                                                 0.779851
# split1_train_score                                                 0.77787
# split2_test_score                                                 0.746269
# split2_train_score                                                0.790349
# split3_test_score                                                 0.753731
# split3_train_score                                                0.784526
# split4_test_score                                                 0.708955
# split4_train_score                                                0.783694
# split5_test_score                                                 0.727612
# split5_train_score                                                0.778286
# split6_test_score                                                 0.738806
# split6_train_score                                                0.783694
# split7_test_score                                                 0.757463
# split7_train_score                                                0.780782
# split8_test_score                                                 0.731343
# split8_train_score                                                0.782446
# split9_test_score                                                 0.735075
# split9_train_score                                                0.781614
# std_fit_time                                                     0.0348401
# std_score_time                                                   0.0265075
# std_test_score                                                   0.0184918
# std_train_score                                                 0.00407059
#
#                                                                         77  \
# mean_fit_time                                                         4.95
# mean_score_time                                                   0.459202
# mean_test_score                                                   0.742537
# mean_train_score                                                  0.772379
# param_knn__n_neighbors                                                  19
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 19, 'svd__n_components': ...
# rank_test_score                                                         10
# split0_test_score                                                     0.75
# split0_train_score                                                0.774958
# split1_test_score                                                 0.772388
# split1_train_score                                                0.768303
# split2_test_score                                                 0.764925
# split2_train_score                                                0.771631
# split3_test_score                                                 0.746269
# split3_train_score                                                0.774126
# split4_test_score                                                 0.708955
# split4_train_score                                                0.779118
# split5_test_score                                                 0.727612
# split5_train_score                                                0.776206
# split6_test_score                                                 0.731343
# split6_train_score                                                0.770383
# split7_test_score                                                 0.772388
# split7_train_score                                                0.769551
# split8_test_score                                                 0.738806
# split8_train_score                                                0.770383
# split9_test_score                                                 0.712687
# split9_train_score                                                0.769135
# std_fit_time                                                      0.444188
# std_score_time                                                   0.0889072
# std_test_score                                                   0.0217573
# std_train_score                                                  0.0033681
#
#                                                ...                          \
# mean_fit_time                                  ...
# mean_score_time                                ...
# mean_test_score                                ...
# mean_train_score                               ...
# param_knn__n_neighbors                         ...
# param_svd__n_components                        ...
# param_tfidf__min_df                            ...
# params                                         ...
# rank_test_score                                ...
# split0_test_score                              ...
# split0_train_score                             ...
# split1_test_score                              ...
# split1_train_score                             ...
# split2_test_score                              ...
# split2_train_score                             ...
# split3_test_score                              ...
# split3_train_score                             ...
# split4_test_score                              ...
# split4_train_score                             ...
# split5_test_score                              ...
# split5_train_score                             ...
# split6_test_score                              ...
# split6_train_score                             ...
# split7_test_score                              ...
# split7_train_score                             ...
# split8_test_score                              ...
# split8_train_score                             ...
# split9_test_score                              ...
# split9_train_score                             ...
# std_fit_time                                   ...
# std_score_time                                 ...
# std_test_score                                 ...
# std_train_score                                ...
#
#                                                                         24  \
# mean_fit_time                                                      6.71704
# mean_score_time                                                   0.477963
# mean_test_score                                                   0.701866
# mean_train_score                                                  0.798087
# param_knn__n_neighbors                                                   7
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 7, 'svd__n_components': 1...
# rank_test_score                                                         71
# split0_test_score                                                 0.708955
# split0_train_score                                                0.798253
# split1_test_score                                                 0.742537
# split1_train_score                                                0.787854
# split2_test_score                                                 0.708955
# split2_train_score                                                0.795757
# split3_test_score                                                 0.690299
# split3_train_score                                                0.802829
# split4_test_score                                                 0.656716
# split4_train_score                                                0.804077
# split5_test_score                                                 0.705224
# split5_train_score                                                0.802413
# split6_test_score                                                 0.727612
# split6_train_score                                                0.797421
# split7_test_score                                                 0.723881
# split7_train_score                                                0.792845
# split8_test_score                                                 0.664179
# split8_train_score                                                0.801165
# split9_test_score                                                 0.690299
# split9_train_score                                                0.798253
# std_fit_time                                                      0.261303
# std_score_time                                                   0.0391477
# std_test_score                                                   0.0257679
# std_train_score                                                 0.00473991
#
#                                                                         17  \
# mean_fit_time                                                      4.94768
# mean_score_time                                                   0.452283
# mean_test_score                                                   0.700746
# mean_train_score                                                   0.81406
# param_knn__n_neighbors                                                   5
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 5, 'svd__n_components': 1...
# rank_test_score                                                         73
# split0_test_score                                                 0.738806
# split0_train_score                                                0.810732
# split1_test_score                                                 0.735075
# split1_train_score                                                0.813228
# split2_test_score                                                 0.671642
# split2_train_score                                                0.819468
# split3_test_score                                                 0.675373
# split3_train_score                                                0.814892
# split4_test_score                                                 0.619403
# split4_train_score                                                 0.81822
# split5_test_score                                                 0.723881
# split5_train_score                                                0.817388
# split6_test_score                                                 0.716418
# split6_train_score                                                0.809068
# split7_test_score                                                 0.735075
# split7_train_score                                                0.813644
# split8_test_score                                                 0.697761
# split8_train_score                                                0.815308
# split9_test_score                                                  0.69403
# split9_train_score                                                0.808652
# std_fit_time                                                      0.120336
# std_score_time                                                   0.0368419
# std_test_score                                                   0.0357041
# std_train_score                                                 0.00354921
#
#                                                                         9   \
# mean_fit_time                                                      4.00043
# mean_score_time                                                   0.321445
# mean_test_score                                                    0.69403
# mean_train_score                                                  0.780824
# param_knn__n_neighbors                                                   5
# param_svd__n_components                                                 10
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 5, 'svd__n_components': 1...
# rank_test_score                                                         74
# split0_test_score                                                 0.712687
# split0_train_score                                                0.776206
# split1_test_score                                                 0.731343
# split1_train_score                                                0.774542
# split2_test_score                                                 0.660448
# split2_train_score                                                0.784942
# split3_test_score                                                 0.686567
# split3_train_score                                                0.776622
# split4_test_score                                                 0.649254
# split4_train_score                                                0.784942
# split5_test_score                                                 0.690299
# split5_train_score                                                 0.77995
# split6_test_score                                                 0.701493
# split6_train_score                                                0.781198
# split7_test_score                                                 0.720149
# split7_train_score                                                0.782446
# split8_test_score                                                 0.686567
# split8_train_score                                                 0.78619
# split9_test_score                                                 0.701493
# split9_train_score                                                0.781198
# std_fit_time                                                      0.239863
# std_score_time                                                   0.0316858
# std_test_score                                                   0.0240664
# std_train_score                                                 0.00380542
#
#                                                                         16  \
# mean_fit_time                                                      5.30802
# mean_score_time                                                    0.45594
# mean_test_score                                                    0.69403
# mean_train_score                                                  0.814559
# param_knn__n_neighbors                                                   5
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 5, 'svd__n_components': 1...
# rank_test_score                                                         74
# split0_test_score                                                 0.708955
# split0_train_score                                                0.814476
# split1_test_score                                                 0.742537
# split1_train_score                                                0.808652
# split2_test_score                                                  0.66791
# split2_train_score                                                0.819884
# split3_test_score                                                 0.679104
# split3_train_score                                                0.818636
# split4_test_score                                                  0.63806
# split4_train_score                                                 0.81614
# split5_test_score                                                 0.705224
# split5_train_score                                                0.814476
# split6_test_score                                                 0.720149
# split6_train_score                                                0.806572
# split7_test_score                                                 0.708955
# split7_train_score                                                 0.81406
# split8_test_score                                                 0.686567
# split8_train_score                                                0.821131
# split9_test_score                                                 0.682836
# split9_train_score                                                0.811564
# std_fit_time                                                     0.0912735
# std_score_time                                                   0.0316593
# std_test_score                                                   0.0279726
# std_train_score                                                 0.00445616
#
#                                                                         8   \
# mean_fit_time                                                      5.22977
# mean_score_time                                                   0.462117
# mean_test_score                                                   0.686194
# mean_train_score                                                   0.85129
# param_knn__n_neighbors                                                   3
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 3, 'svd__n_components': 1...
# rank_test_score                                                         76
# split0_test_score                                                 0.690299
# split0_train_score                                                0.849834
# split1_test_score                                                 0.712687
# split1_train_score                                                 0.85025
# split2_test_score                                                 0.675373
# split2_train_score                                                0.850666
# split3_test_score                                                 0.664179
# split3_train_score                                                0.855241
# split4_test_score                                                 0.626866
# split4_train_score                                                0.853577
# split5_test_score                                                 0.697761
# split5_train_score                                                0.849002
# split6_test_score                                                  0.66791
# split6_train_score                                                0.852745
# split7_test_score                                                 0.716418
# split7_train_score                                                0.849834
# split8_test_score                                                 0.682836
# split8_train_score                                                0.857321
# split9_test_score                                                 0.727612
# split9_train_score                                                0.844426
# std_fit_time                                                       0.15014
# std_score_time                                                   0.0345942
# std_test_score                                                   0.0281933
# std_train_score                                                 0.00342642
#
#                                                                         7   \
# mean_fit_time                                                      5.52628
# mean_score_time                                                    0.47197
# mean_test_score                                                    0.68209
# mean_train_score                                                   0.84975
# param_knn__n_neighbors                                                   3
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 3, 'svd__n_components': 1...
# rank_test_score                                                         77
# split0_test_score                                                 0.645522
# split0_train_score                                                0.844842
# split1_test_score                                                 0.716418
# split1_train_score                                                0.849834
# split2_test_score                                                 0.671642
# split2_train_score                                                0.860233
# split3_test_score                                                 0.679104
# split3_train_score                                                0.843178
# split4_test_score                                                  0.63806
# split4_train_score                                                0.845258
# split5_test_score                                                 0.705224
# split5_train_score                                                0.858569
# split6_test_score                                                 0.682836
# split6_train_score                                                0.853993
# split7_test_score                                                 0.679104
# split7_train_score                                                 0.85025
# split8_test_score                                                 0.671642
# split8_train_score                                                0.850666
# split9_test_score                                                 0.731343
# split9_train_score                                                0.840682
# std_fit_time                                                      0.223164
# std_score_time                                                      0.0416
# std_test_score                                                   0.0276623
# std_train_score                                                 0.00613557
#
#                                                                         2   \
# mean_fit_time                                                      3.30377
# mean_score_time                                                   0.313724
# mean_test_score                                                   0.680597
# mean_train_score                                                  0.814309
# param_knn__n_neighbors                                                   3
# param_svd__n_components                                                 10
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 3, 'svd__n_components': 1...
# rank_test_score                                                         78
# split0_test_score                                                 0.697761
# split0_train_score                                                0.806572
# split1_test_score                                                 0.720149
# split1_train_score                                                0.806572
# split2_test_score                                                 0.656716
# split2_train_score                                                0.825707
# split3_test_score                                                  0.69403
# split3_train_score                                                0.813644
# split4_test_score                                                 0.619403
# split4_train_score                                                0.820715
# split5_test_score                                                 0.652985
# split5_train_score                                                0.820715
# split6_test_score                                                 0.671642
# split6_train_score                                                 0.81198
# split7_test_score                                                 0.679104
# split7_train_score                                                 0.81614
# split8_test_score                                                 0.701493
# split8_train_score                                                0.813644
# split9_test_score                                                 0.712687
# split9_train_score                                                0.807404
# std_fit_time                                                      0.113485
# std_score_time                                                   0.0332025
# std_test_score                                                   0.0294374
# std_train_score                                                 0.00623738
#
#                                                                         6   \
# mean_fit_time                                                      7.02309
# mean_score_time                                                   0.504009
# mean_test_score                                                   0.679851
# mean_train_score                                                  0.847671
# param_knn__n_neighbors                                                   3
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 3, 'svd__n_components': 1...
# rank_test_score                                                         79
# split0_test_score                                                  0.66791
# split0_train_score                                                 0.84817
# split1_test_score                                                 0.720149
# split1_train_score                                                0.842762
# split2_test_score                                                  0.66791
# split2_train_score                                                0.855241
# split3_test_score                                                 0.675373
# split3_train_score                                                 0.85025
# split4_test_score                                                 0.630597
# split4_train_score                                                0.845674
# split5_test_score                                                 0.708955
# split5_train_score                                                0.855657
# split6_test_score                                                 0.690299
# split6_train_score                                                0.849418
# split7_test_score                                                 0.690299
# split7_train_score                                                0.840682
# split8_test_score                                                 0.656716
# split8_train_score                                                0.849002
# split9_test_score                                                 0.690299
# split9_train_score                                                 0.83985
# std_fit_time                                                      0.809283
# std_score_time                                                    0.118409
# std_test_score                                                   0.0246269
# std_train_score                                                 0.00520482
#
#                                                                         1   \
# mean_fit_time                                                      3.41065
# mean_score_time                                                   0.308408
# mean_test_score                                                   0.674254
# mean_train_score                                                  0.813852
# param_knn__n_neighbors                                                   3
# param_svd__n_components                                                 10
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 3, 'svd__n_components': 1...
# rank_test_score                                                         80
# split0_test_score                                                  0.69403
# split0_train_score                                                0.806156
# split1_test_score                                                 0.705224
# split1_train_score                                                0.802829
# split2_test_score                                                 0.652985
# split2_train_score                                                0.822379
# split3_test_score                                                  0.69403
# split3_train_score                                                0.815724
# split4_test_score                                                 0.615672
# split4_train_score                                                0.826955
# split5_test_score                                                 0.660448
# split5_train_score                                                0.813644
# split6_test_score                                                  0.66791
# split6_train_score                                                0.809484
# split7_test_score                                                 0.686567
# split7_train_score                                                0.813644
# split8_test_score                                                 0.675373
# split8_train_score                                                0.815724
# split9_test_score                                                 0.690299
# split9_train_score                                                 0.81198
# std_fit_time                                                      0.110901
# std_score_time                                                   0.0248116
# std_test_score                                                   0.0250334
# std_train_score                                                 0.00674403
#
#                                                                         0
# mean_fit_time                                                      3.85253
# mean_score_time                                                   0.322744
# mean_test_score                                                   0.671269
# mean_train_score                                                  0.805657
# param_knn__n_neighbors                                                   3
# param_svd__n_components                                                 10
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 3, 'svd__n_components': 1...
# rank_test_score                                                         81
# split0_test_score                                                 0.679104
# split0_train_score                                                0.801581
# split1_test_score                                                 0.712687
# split1_train_score                                                0.806572
# split2_test_score                                                 0.641791
# split2_train_score                                                0.811564
# split3_test_score                                                 0.671642
# split3_train_score                                                0.801581
# split4_test_score                                                 0.623134
# split4_train_score                                                0.811564
# split5_test_score                                                  0.66791
# split5_train_score                                                0.806988
# split6_test_score                                                 0.671642
# split6_train_score                                                0.804908
# split7_test_score                                                  0.69403
# split7_train_score                                                0.806156
# split8_test_score                                                 0.664179
# split8_train_score                                                0.804077
# split9_test_score                                                 0.686567
# split9_train_score                                                0.801581
# std_fit_time                                                      0.157108
# std_score_time                                                   0.0374052
# std_test_score                                                   0.0240346
# std_train_score                                                 0.00354335
#
# [33 rows x 81 columns]

# %%
gs_pipe.best_params_
# Out:
# {'knn__n_neighbors': 17, 'svd__n_components': 50, 'tfidf__min_df': 3}

# %%
plt.figure(figsize=(10,10))
plt.xticks(range(3,20,2),range(3,20,2))

for n_comp in params['svd__n_components']:
    plt.plot(gs_pipe_df['param_knn__n_neighbors'][gs_pipe_df['param_svd__n_components'] == n_comp], 
             gs_pipe_df['mean_train_score'][gs_pipe_df['param_svd__n_components'] == n_comp],
             '-^',label='n_components={}_train'.format(n_comp))
    plt.plot(gs_pipe_df['param_knn__n_neighbors'][gs_pipe_df['param_svd__n_components'] == n_comp], 
             gs_pipe_df['mean_test_score'][gs_pipe_df['param_svd__n_components'] == n_comp],
             '-o',label='n_components={}_test'.format(n_comp))
    plt.xlabel('n_neighbors')
    plt.ylabel('mean_score')
    plt.title('Mean train and test scores vs KNN n_neighbors for different SVD n_components')
    plt.legend()

# %%
sum(10*gs_pipe_df['mean_fit_time']+10*gs_pipe_df['mean_score_time'])/60
# Out:
# 66.616353535652166

# %%
knn_model.classes_
# Out:
# array(['Aerospace_engineering', 'Artificial_intelligence',
#        'Bioinformatics', 'Biological_engineering', 'Business_intelligence',
#        'Computational_statistics', 'Data_analysis',
#        'Electrical_engineering', 'Information_science', 'Machine_learning',
#        'Mechanical_engineering', 'Operations_research', 'Robotics',
#        'Software_engineering', 'Systems_engineering'], dtype=object)

# %%
knn_model.predict_proba(preprocess_search_text(wikipedia.page(pageid=13494976).content,lsa_vectorizer,fit_svd))
# Out:
# array([[ 0.        ,  0.70588235,  0.        ,  0.        ,  0.05882353,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.11764706,
#          0.        ,  0.05882353,  0.05882353,  0.        ,  0.        ]])

# %% [markdown]
# ## Performing predictions on uncollected articles with the trained model

# %%
uncollected_articles_dict = pickle.loads(r.get('uncollected_articles'))
lsa_vectorizer = pickle.loads(r.get('vectorizer'))
fit_svd = pickle.loads(r.get('fit_svd'))
knn_model = pickle.loads(r.get('knn_model'))
pageid_title_df = pickle.loads(r.get('pageid_title_df'))

new_article_ids = []
for val in uncollected_articles_dict.values():
    if len(val) != 0:
        for i in val:
            new_article_ids.append(i)

correct = []
false_pred_ids = {}
            
for artid in new_article_ids:
    article_text = wikipedia.page(pageid=artid).content
    predict_lsa = preprocess_search_text(article_text,lsa_vectorizer,fit_svd)
    title = pageid_title_df['title'][pageid_title_df['pageid'] == int(artid)].values[0]
    actual = pageid_title_df['category'][pageid_title_df['pageid'] == int(artid)].values[0]
    predicted = knn_model.predict(predict_lsa)[0]
    probabilities = knn_model.predict_proba(predict_lsa)
    max_probability = probabilities.max()
    correct.append([actual == predicted][0])
    if [actual == predicted][0] == False:
        false_pred_ids[artid] = [title,actual,predicted,max_probability]
    print("\nPage ID:", artid)
    print('Title:', title)
    print("Actual Category:", actual)
    print("Predicted Category:", predicted)
    print("Confidence Score:", round(max_probability,2))
    print("Correct prediction:", [actual == predicted][0])

print("\nTotal number of predictions:", len(correct))
print("Percent of correct predictions:", sum(correct)/len(correct))
# Out:
# Page ID: 13494976
# Title: CALO
# Actual Category: Artificial_intelligence
# Predicted Category: Artificial_intelligence
# Confidence Score: 0.71
# Correct prediction: True
#
# Page ID: 36298401
# Title: DAYDREAMER
# Actual Category: Artificial_intelligence
# Predicted Category: Artificial_intelligence
# Confidence Score: 0.53
# Correct prediction: True
#
# Page ID: 37394465
# Title: KAoS
# Actual Category: Artificial_intelligence
# Predicted Category: Artificial_intelligence
# Confidence Score: 0.59
# Correct prediction: True
#
# Page ID: 48834013
# Title: DAVI
# Actual Category: Robotics
# Predicted Category: Mechanical_engineering
# Confidence Score: 0.29
# Correct prediction: False
#
# Page ID: 3678414
# Title: EMBOSS
# Actual Category: Bioinformatics
# Predicted Category: Bioinformatics
# Confidence Score: 0.94
# Correct prediction: True
#
# Page ID: 14072373
# Title: EMBRACE
# Actual Category: Bioinformatics
# Predicted Category: Bioinformatics
# Confidence Score: 0.76
# Correct prediction: True
#
# Page ID: 17727869
# Title: ITools Resourceome
# Actual Category: Bioinformatics
# Predicted Category: Bioinformatics
# Confidence Score: 0.94
# Correct prediction: True
#
# Page ID: 20720013
# Title: MOWSE
# Actual Category: Bioinformatics
# Predicted Category: Bioinformatics
# Confidence Score: 0.88
# Correct prediction: True
#
# Page ID: 40091615
# Title: PANTHER
# Actual Category: Bioinformatics
# Predicted Category: Bioinformatics
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 13431106
# Title: PRINTS
# Actual Category: Bioinformatics
# Predicted Category: Bioinformatics
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 17360543
# Title: Maths, Stats & OR Network
# Actual Category: Operations_research
# Predicted Category: Information_science
# Confidence Score: 0.29
# Correct prediction: False
#
# Page ID: 33936753
# Title: Library, Information Science & Technology Abstracts
# Actual Category: Information_science
# Predicted Category: Information_science
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 44585403
# Title: CROC
# Actual Category: Systems_engineering
# Predicted Category: Business_intelligence
# Confidence Score: 0.76
# Correct prediction: False
#
# Page ID: 4566423
# Title: PREview
# Actual Category: Systems_engineering
# Predicted Category: Systems_engineering
# Confidence Score: 0.82
# Correct prediction: True
#
# Total number of predictions: 14
# Percent of correct predictions: 0.7857142857142857

# %% [markdown]
# ## Performing searches on the same articles and comparing to the above predictions

# %%
for i in false_pred_ids.keys():
    search_article_text = wikipedia.page(pageid=i).content

    vectorizer, fitted_svd, lsa = fit_svd_for_lsa(article_contents_df['clean_text'])

    search_lsa = preprocess_search_text(search_article_text,vectorizer,fitted_svd)

    top_five, top_text = five_most_similar_docs(lsa,search_lsa,article_contents_df)

    print("\n\nSearch text:\n")
    print("Title:", false_pred_ids[i][0])
    print("Actual Category:", false_pred_ids[i][1])
    print("Predicted Category:", false_pred_ids[i][2])
    print("Confidence Score:", false_pred_ids[i][3])
    print("Introduction:", search_article_text.split('\n',1)[0])

    print("\n")
    print("The top 5 related articles are the following:\n")
    print(top_five[['category','title']],"\n\n")

    print("The text from the top related article is below:\n")
    print("Title:", top_text[['title']][0],"\n")
    print("Category:", top_text[['category']][0],"\n")
    print("Website: https://en.wikipedia.org/wiki/{}".format(re.sub('\s','_',top_text[['title']][0])),"\n")
    print("Introduction:", top_text[['clean_text']][0].split('\n',1)[0])
# Out:
# Search text:
#
# Title: DAVI
# Actual Category: Robotics
# Predicted Category: Mechanical_engineering
# Confidence Score: 0.294117647059
# Introduction: The Dutch Automated Vehicle Initiative (DAVI) is a research and demonstration initiative developing automated vehicles for use on public roads.
#
#
# The top 5 related articles are the following:
#
#                     category              title
# 726                 Robotics     Autonomous car
# 729                 Robotics  Autonomous Things
# 2403  Mechanical_engineering     Railworthiness
# 763                 Robotics    LUTZ Pathfinder
# 2305  Mechanical_engineering      Drive by wire
#
#
# The text from the top related article is below:
#
# Title: Autonomous car
#
# Category: Robotics
#
# Website: https://en.wikipedia.org/wiki/Autonomous_car
#
# Introduction: An autonomous car (also known as a driverless car, auto, self-driving car, robotic car) is a vehicle that is capable of sensing its environment and navigating without human input. Many such vehicles are being developed, but as of May 2017 automated cars permitted on public roads are not yet fully autonomous. They all require a human driver at the wheel who is ready at a moment's notice to take control of the vehicle.
#
#
# Search text:
#
# Title: Maths, Stats & OR Network
# Actual Category: Operations_research
# Predicted Category: Information_science
# Confidence Score: 0.294117647059
# Introduction: The former Maths, Stats & OR Network (MSOR) of the Higher Education Academy of the United Kingdom was a subject-specific support network for enhancing the student learning experience in Mathematics, Statistics and Operations Research but has now closed. Maths, Stats & OR remains a discipline area of the Higher Education Academy.
#
#
# The top 5 related articles are the following:
#
#                  category                                     title
# 182      Machine_learning                         Transfer learning
# 118      Machine_learning  User:Mkai91/sandbox/Deep Learning Studio
# 1702  Information_science              Organizational metacognition
# 1        Machine_learning               Outline of machine learning
# 188      Machine_learning                     Unsupervised learning
#
#
# The text from the top related article is below:
#
# Title: Transfer learning
#
# Category: Machine_learning
#
# Website: https://en.wikipedia.org/wiki/Transfer_learning
#
# Introduction: Transfer learning or inductive transfer is a research problem in machine learning that focuses on storing knowledge gained while solving one problem and applying it to a different but related problem. For example, knowledge gained while learning to recognize cars could apply when trying to recognize trucks. This area of research bears some relation to the long history of psychological literature on transfer of learning, although formal ties between the two fields are limited.
#
#
# Search text:
#
# Title: CROC
# Actual Category: Systems_engineering
# Predicted Category: Business_intelligence
# Confidence Score: 0.764705882353
# Introduction: CROC (CROC incorporated) is a Russian systems integrator  and one of the top 10 IT companies in Russia.
#
#
# The top 5 related articles are the following:
#
#                   category                                              title
# 220  Business_intelligence                     Business intelligence software
# 221  Business_intelligence                    Business performance management
# 211  Business_intelligence                                            Arcplan
# 284  Business_intelligence                                Klipfolio Dashboard
# 269  Business_intelligence  Hybrid Transactional/Analytical Processing (HTAP)
#
#
# The text from the top related article is below:
#
# Title: Business intelligence software
#
# Category: Business_intelligence
#
# Website: https://en.wikipedia.org/wiki/Business_intelligence_software
#
# Introduction: Business intelligence software is a type of application software designed to retrieve, analyze, transform and report data for business intelligence. The applications generally read data that have been previously stored, often, though not necessarily, in a data warehouse or data mart.

# %%
gs_pipe_df[gs_pipe_df['param_tfidf__min_df'] == 1][gs_pipe_df['param_svd__n_components'] == 100].sort_values('rank_test_score').T
# Out:
#                                                                         78  \
# mean_fit_time                                                      7.48888
# mean_score_time                                                   0.543584
# mean_test_score                                                   0.721269
# mean_train_score                                                  0.768927
# param_knn__n_neighbors                                                  19
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 19, 'svd__n_components': ...
# rank_test_score                                                         28
# split0_test_score                                                 0.753731
# split0_train_score                                                0.765391
# split1_test_score                                                 0.720149
# split1_train_score                                                0.768719
# split2_test_score                                                 0.731343
# split2_train_score                                                0.770799
# split3_test_score                                                 0.742537
# split3_train_score                                                0.770799
# split4_test_score                                                 0.690299
# split4_train_score                                                 0.77787
# split5_test_score                                                 0.708955
# split5_train_score                                                0.772463
# split6_test_score                                                 0.712687
# split6_train_score                                                0.761231
# split7_test_score                                                 0.731343
# split7_train_score                                                0.763311
# split8_test_score                                                  0.69403
# split8_train_score                                                0.769967
# split9_test_score                                                 0.727612
# split9_train_score                                                0.768719
# std_fit_time                                                      0.572845
# std_score_time                                                   0.0600962
# std_test_score                                                   0.0191756
# std_train_score                                                 0.00451575
#
#                                                                         60  \
# mean_fit_time                                                      6.47983
# mean_score_time                                                   0.457179
# mean_test_score                                                   0.714179
# mean_train_score                                                  0.774875
# param_knn__n_neighbors                                                  15
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 15, 'svd__n_components': ...
# rank_test_score                                                         35
# split0_test_score                                                 0.742537
# split0_train_score                                                0.776206
# split1_test_score                                                 0.705224
# split1_train_score                                                0.771631
# split2_test_score                                                 0.735075
# split2_train_score                                                0.777454
# split3_test_score                                                 0.701493
# split3_train_score                                                0.777454
# split4_test_score                                                 0.686567
# split4_train_score                                                0.776206
# split5_test_score                                                 0.708955
# split5_train_score                                                0.775374
# split6_test_score                                                 0.712687
# split6_train_score                                                0.769967
# split7_test_score                                                 0.742537
# split7_train_score                                                0.769551
# split8_test_score                                                 0.697761
# split8_train_score                                                0.778702
# split9_test_score                                                 0.708955
# split9_train_score                                                0.776206
# std_fit_time                                                     0.0751132
# std_score_time                                                   0.0286937
# std_test_score                                                   0.0183709
# std_train_score                                                 0.00310618
#
#                                                                         51  \
# mean_fit_time                                                       6.4963
# mean_score_time                                                   0.457311
# mean_test_score                                                   0.713806
# mean_train_score                                                  0.778661
# param_knn__n_neighbors                                                  13
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 13, 'svd__n_components': ...
# rank_test_score                                                         37
# split0_test_score                                                 0.735075
# split0_train_score                                                0.780366
# split1_test_score                                                 0.712687
# split1_train_score                                                0.779118
# split2_test_score                                                 0.727612
# split2_train_score                                                0.778286
# split3_test_score                                                 0.712687
# split3_train_score                                                0.781198
# split4_test_score                                                 0.690299
# split4_train_score                                                0.780782
# split5_test_score                                                 0.712687
# split5_train_score                                                 0.77787
# split6_test_score                                                 0.708955
# split6_train_score                                                0.774958
# split7_test_score                                                 0.727612
# split7_train_score                                                 0.77579
# split8_test_score                                                 0.705224
# split8_train_score                                                0.782446
# split9_test_score                                                 0.705224
# split9_train_score                                                 0.77579
# std_fit_time                                                      0.501923
# std_score_time                                                   0.0338514
# std_test_score                                                    0.012493
# std_train_score                                                 0.00243584
#
#                                                                         69  \
# mean_fit_time                                                      6.54659
# mean_score_time                                                   0.462238
# mean_test_score                                                    0.71194
# mean_train_score                                                  0.772088
# param_knn__n_neighbors                                                  17
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 17, 'svd__n_components': ...
# rank_test_score                                                         44
# split0_test_score                                                 0.753731
# split0_train_score                                                0.771215
# split1_test_score                                                 0.712687
# split1_train_score                                                0.773295
# split2_test_score                                                 0.727612
# split2_train_score                                                0.776206
# split3_test_score                                                 0.716418
# split3_train_score                                                0.772879
# split4_test_score                                                 0.671642
# split4_train_score                                                0.776206
# split5_test_score                                                 0.682836
# split5_train_score                                                0.774126
# split6_test_score                                                 0.716418
# split6_train_score                                                0.762895
# split7_test_score                                                 0.727612
# split7_train_score                                                0.767887
# split8_test_score                                                 0.690299
# split8_train_score                                                0.774542
# split9_test_score                                                 0.720149
# split9_train_score                                                0.771631
# std_fit_time                                                      0.285162
# std_score_time                                                   0.0246067
# std_test_score                                                   0.0229894
# std_train_score                                                 0.00386408
#
#                                                                         42  \
# mean_fit_time                                                      6.49409
# mean_score_time                                                    0.45981
# mean_test_score                                                   0.711567
# mean_train_score                                                  0.786814
# param_knn__n_neighbors                                                  11
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 11, 'svd__n_components': ...
# rank_test_score                                                         47
# split0_test_score                                                 0.742537
# split0_train_score                                                0.785358
# split1_test_score                                                 0.735075
# split1_train_score                                                0.787854
# split2_test_score                                                 0.705224
# split2_train_score                                                 0.78827
# split3_test_score                                                 0.705224
# split3_train_score                                                0.789933
# split4_test_score                                                 0.675373
# split4_train_score                                                 0.78827
# split5_test_score                                                 0.723881
# split5_train_score                                                0.792013
# split6_test_score                                                 0.716418
# split6_train_score                                                0.778702
# split7_test_score                                                 0.727612
# split7_train_score                                                0.784526
# split8_test_score                                                 0.686567
# split8_train_score                                                0.788686
# split9_test_score                                                 0.697761
# split9_train_score                                                0.784526
# std_fit_time                                                     0.0994679
# std_score_time                                                   0.0267298
# std_test_score                                                   0.0203726
# std_train_score                                                 0.00352106
#
#                                                                         33  \
# mean_fit_time                                                       6.5012
# mean_score_time                                                   0.457713
# mean_test_score                                                   0.708582
# mean_train_score                                                  0.793012
# param_knn__n_neighbors                                                   9
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 9, 'svd__n_components': 1...
# rank_test_score                                                         52
# split0_test_score                                                 0.716418
# split0_train_score                                                0.796173
# split1_test_score                                                 0.735075
# split1_train_score                                                0.790765
# split2_test_score                                                 0.705224
# split2_train_score                                                0.785774
# split3_test_score                                                 0.705224
# split3_train_score                                                0.799501
# split4_test_score                                                 0.686567
# split4_train_score                                                0.801165
# split5_test_score                                                 0.735075
# split5_train_score                                                0.795341
# split6_test_score                                                 0.716418
# split6_train_score                                                0.783278
# split7_test_score                                                 0.708955
# split7_train_score                                                0.794093
# split8_test_score                                                 0.686567
# split8_train_score                                                0.797005
# split9_test_score                                                 0.690299
# split9_train_score                                                0.787022
# std_fit_time                                                      0.109672
# std_score_time                                                   0.0223118
# std_test_score                                                   0.0168903
# std_train_score                                                 0.00573742
#
#                                                                         15  \
# mean_fit_time                                                      6.67744
# mean_score_time                                                   0.471525
# mean_test_score                                                   0.702985
# mean_train_score                                                  0.812438
# param_knn__n_neighbors                                                   5
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 5, 'svd__n_components': 1...
# rank_test_score                                                         65
# split0_test_score                                                 0.712687
# split0_train_score                                                0.815724
# split1_test_score                                                 0.761194
# split1_train_score                                                0.804908
# split2_test_score                                                 0.675373
# split2_train_score                                                0.815308
# split3_test_score                                                  0.69403
# split3_train_score                                                 0.81198
# split4_test_score                                                 0.656716
# split4_train_score                                                0.816556
# split5_test_score                                                 0.727612
# split5_train_score                                                0.815724
# split6_test_score                                                 0.712687
# split6_train_score                                                0.804493
# split7_test_score                                                 0.701493
# split7_train_score                                                0.806988
# split8_test_score                                                  0.69403
# split8_train_score                                                0.819468
# split9_test_score                                                  0.69403
# split9_train_score                                                0.813228
# std_fit_time                                                      0.118055
# std_score_time                                                   0.0331162
# std_test_score                                                   0.0270722
# std_train_score                                                 0.00496544
#
#                                                                         24  \
# mean_fit_time                                                      6.71704
# mean_score_time                                                   0.477963
# mean_test_score                                                   0.701866
# mean_train_score                                                  0.798087
# param_knn__n_neighbors                                                   7
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 7, 'svd__n_components': 1...
# rank_test_score                                                         71
# split0_test_score                                                 0.708955
# split0_train_score                                                0.798253
# split1_test_score                                                 0.742537
# split1_train_score                                                0.787854
# split2_test_score                                                 0.708955
# split2_train_score                                                0.795757
# split3_test_score                                                 0.690299
# split3_train_score                                                0.802829
# split4_test_score                                                 0.656716
# split4_train_score                                                0.804077
# split5_test_score                                                 0.705224
# split5_train_score                                                0.802413
# split6_test_score                                                 0.727612
# split6_train_score                                                0.797421
# split7_test_score                                                 0.723881
# split7_train_score                                                0.792845
# split8_test_score                                                 0.664179
# split8_train_score                                                0.801165
# split9_test_score                                                 0.690299
# split9_train_score                                                0.798253
# std_fit_time                                                      0.261303
# std_score_time                                                   0.0391477
# std_test_score                                                   0.0257679
# std_train_score                                                 0.00473991
#
#                                                                         6
# mean_fit_time                                                      7.02309
# mean_score_time                                                   0.504009
# mean_test_score                                                   0.679851
# mean_train_score                                                  0.847671
# param_knn__n_neighbors                                                   3
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 3, 'svd__n_components': 1...
# rank_test_score                                                         79
# split0_test_score                                                  0.66791
# split0_train_score                                                 0.84817
# split1_test_score                                                 0.720149
# split1_train_score                                                0.842762
# split2_test_score                                                  0.66791
# split2_train_score                                                0.855241
# split3_test_score                                                 0.675373
# split3_train_score                                                 0.85025
# split4_test_score                                                 0.630597
# split4_train_score                                                0.845674
# split5_test_score                                                 0.708955
# split5_train_score                                                0.855657
# split6_test_score                                                 0.690299
# split6_train_score                                                0.849418
# split7_test_score                                                 0.690299
# split7_train_score                                                0.840682
# split8_test_score                                                 0.656716
# split8_train_score                                                0.849002
# split9_test_score                                                 0.690299
# split9_train_score                                                 0.83985
# std_fit_time                                                      0.809283
# std_score_time                                                    0.118409
# std_test_score                                                   0.0246269
# std_train_score                                                 0.00520482
