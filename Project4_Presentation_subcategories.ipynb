# %%
import pymongo
import pickle
import redis
import matplotlib.pyplot as plt
# %matplotlib inline
import wikipedia
import pandas as pd
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')
import pprint
pp = pprint.PrettyPrinter(indent=1)

rcparams = {'legend.fontsize': 'large',
          'figure.figsize': (10,8),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large',
         'axes.labelweight' : 'bold',
         'axes.titleweight' : 'bold'}
plt.rcParams.update(params)


from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit

from wikipedia_helper import *

# %% [markdown]
# ## Downloading articles

# %%
mgclient = pymongo.MongoClient('54.202.56.110')
wikipedia_db = mgclient.database_names()
mlbi_collector = mgclient.wikipedia_db.mlbi_collector
if mgclient.wikipedia_db.ml_bi_collector.count() != 0:
    mgclient.wikipedia_db.drop_collection(mlbi_collector)
    test_collector = mgclient.wikipedia_db.mlbi_collector

wiki_categories = [line.rstrip('\n') for line in open('mlbi_categories.txt')]
wiki_categories = [line.split(':')[2] for line in wiki_categories]

pageid_title_df, subcat_dict, uncollected_articles = get_article_category_pageid_titles(wiki_categories,mlbi_collector,append_subcats=True)

r = redis.StrictRedis('54.202.56.110')
subcat_dict = pickle.dumps(subcat_dict)
pageid_title_df = pickle.dumps(pageid_title_df)
uncollected_articles = pickle.dumps(uncollected_articles)
r.set('mlbi_subcat_dict',subcat_dict)
r.set('mlbi_pageid_title_df',pageid_title_df)
r.set('mlbi_uncollected_articles',uncollected_articles)
# Out:
# Collecting articles for Machine_learning
# 100%|██████████████████████████████████████████████████████████████████████████████| 1082/1082 [29:12<00:00,  1.73s/it]
# number of articles found: 1082
# number of articles stored: 1077
#
#
# Collecting articles for Business_intelligence
# 100%|██████████████████████████████████████████████████████████████████████████████| 1243/1243 [32:27<00:00,  1.53s/it]
# number of articles found: 1243
# number of articles stored: 2312
#
# Machine_learning has 1082 articles.
# Business_intelligence has 1243 articles.
# The total number of unique articles found is 2325.
# The total number of articles stored is 2312.
# True

# %% [markdown]
# ## Training a model

# %%
print("\nRetrieving article texts...")

curs_test = mgclient.wikipedia_db.mlbi_collector.find()

article_contents_df = get_clean_mongo_dataframe(load_wiki_docs(curs_test,mgclient.wikipedia_db.mlbi_collector.count()))

pipe = Pipeline([('tfidf',TfidfVectorizer(stop_words = 'english')),
               ('svd', TruncatedSVD(random_state=12)),
               ('knn', KNeighborsClassifier())])

params = {
            'tfidf__min_df' : [1,2,3],
            'svd__n_components' : [10,50,100],
            'knn__n_neighbors' : range(3,20,2)
}

print("\nFitting the model now...")

gs_pipe = GridSearchCV(pipe, param_grid=params,cv=StratifiedShuffleSplit(random_state=12))
gs_pipe.fit(article_contents_df['clean_text'],article_contents_df['category'])

r = redis.StrictRedis('54.202.56.110')
all_models = pickle.dumps(gs_pipe)
best_models = pickle.dumps(gs_pipe.best_estimator_)
lsa_vectorizer = pickle.dumps(gs_pipe.best_estimator_.steps[0][1])
fit_svd = pickle.dumps(gs_pipe.best_estimator_.steps[1][1])
knn_model = pickle.dumps(gs_pipe.best_estimator_.steps[2][1])
article_df = pickle.dumps(article_contents_df)
r.set('mlbi_all_models',all_models)
r.set('mlbi_best_model',best_models)
r.set('mlbi_vectorizer',lsa_vectorizer)
r.set('mlbi_fit_svd',fit_svd)
r.set('mlbi_knn_model',knn_model)
r.set('mlbi_article_data_df',article_df)

print("\nThe model is ready to make predictions!")
# Out:
# Retrieving article texts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 2312/2312 [05:16<00:00,  7.30it/s]
# Fitting the model now...
#
# The model is ready to make predictions!

# %%
gs_pipe_df = pd.DataFrame(gs_pipe.cv_results_)
gs_pipe_df.sort_values('rank_test_score').T
# Out:
#                                                                         14  \
# mean_fit_time                                                        2.713
# mean_score_time                                                   0.264983
# mean_test_score                                                   0.958874
# mean_train_score                                                  0.970319
# param_knn__n_neighbors                                                   5
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 5, 'svd__n_components': 5...
# rank_test_score                                                          1
# split0_test_score                                                 0.952381
# split0_train_score                                                0.971042
# split1_test_score                                                 0.948052
# split1_train_score                                                0.969112
# split2_test_score                                                 0.965368
# split2_train_score                                                0.967181
# split3_test_score                                                 0.930736
# split3_train_score                                                0.973938
# split4_test_score                                                 0.978355
# split4_train_score                                                0.965251
# split5_test_score                                                 0.969697
# split5_train_score                                                0.974903
# split6_test_score                                                 0.948052
# split6_train_score                                                 0.97056
# split7_test_score                                                 0.961039
# split7_train_score                                                0.970077
# split8_test_score                                                 0.969697
# split8_train_score                                                0.969112
# split9_test_score                                                 0.965368
# split9_train_score                                                0.972008
# std_fit_time                                                     0.0938157
# std_score_time                                                   0.0269324
# std_test_score                                                   0.0133077
# std_train_score                                                 0.00275773
#
#                                                                         22  \
# mean_fit_time                                                      2.76929
# mean_score_time                                                   0.264004
# mean_test_score                                                   0.958442
# mean_train_score                                                  0.966313
# param_knn__n_neighbors                                                   7
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 7, 'svd__n_components': 5...
# rank_test_score                                                          2
# split0_test_score                                                 0.952381
# split0_train_score                                                0.966699
# split1_test_score                                                 0.939394
# split1_train_score                                                0.966699
# split2_test_score                                                 0.974026
# split2_train_score                                                 0.96332
# split3_test_score                                                 0.935065
# split3_train_score                                                0.972008
# split4_test_score                                                 0.982684
# split4_train_score                                                0.963803
# split5_test_score                                                 0.961039
# split5_train_score                                                0.967181
# split6_test_score                                                 0.943723
# split6_train_score                                                0.966216
# split7_test_score                                                  0.95671
# split7_train_score                                                0.968147
# split8_test_score                                                 0.974026
# split8_train_score                                                0.962355
# split9_test_score                                                 0.965368
# split9_train_score                                                0.966699
# std_fit_time                                                     0.0441345
# std_score_time                                                   0.0234539
# std_test_score                                                   0.0151453
# std_train_score                                                 0.00260618
#
#                                                                         32  \
# mean_fit_time                                                      2.90813
# mean_score_time                                                   0.297168
# mean_test_score                                                   0.957143
# mean_train_score                                                  0.963948
# param_knn__n_neighbors                                                   9
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 9, 'svd__n_components': 5...
# rank_test_score                                                          3
# split0_test_score                                                 0.952381
# split0_train_score                                                0.965734
# split1_test_score                                                 0.943723
# split1_train_score                                                0.965251
# split2_test_score                                                 0.965368
# split2_train_score                                                 0.96139
# split3_test_score                                                 0.930736
# split3_train_score                                                0.965734
# split4_test_score                                                 0.982684
# split4_train_score                                                0.961873
# split5_test_score                                                 0.961039
# split5_train_score                                                0.962838
# split6_test_score                                                 0.943723
# split6_train_score                                                 0.96332
# split7_test_score                                                  0.95671
# split7_train_score                                                0.966216
# split8_test_score                                                 0.978355
# split8_train_score                                                0.960425
# split9_test_score                                                  0.95671
# split9_train_score                                                0.966699
# std_fit_time                                                      0.131194
# std_score_time                                                   0.0340925
# std_test_score                                                   0.0150522
# std_train_score                                                 0.00213722
#
#                                                                         23  \
# mean_fit_time                                                      2.63299
# mean_score_time                                                   0.260304
# mean_test_score                                                    0.95671
# mean_train_score                                                  0.966844
# param_knn__n_neighbors                                                   7
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 7, 'svd__n_components': 5...
# rank_test_score                                                          4
# split0_test_score                                                 0.961039
# split0_train_score                                                0.969595
# split1_test_score                                                 0.943723
# split1_train_score                                                0.969595
# split2_test_score                                                 0.969697
# split2_train_score                                                0.964768
# split3_test_score                                                 0.935065
# split3_train_score                                                0.968147
# split4_test_score                                                 0.978355
# split4_train_score                                                 0.96332
# split5_test_score                                                 0.961039
# split5_train_score                                                0.969112
# split6_test_score                                                 0.939394
# split6_train_score                                                0.968629
# split7_test_score                                                 0.948052
# split7_train_score                                                0.967664
# split8_test_score                                                 0.974026
# split8_train_score                                                0.963803
# split9_test_score                                                  0.95671
# split9_train_score                                                0.963803
# std_fit_time                                                     0.0601637
# std_score_time                                                   0.0258204
# std_test_score                                                   0.0140942
# std_train_score                                                 0.00247084
#
#                                                                         67  \
# mean_fit_time                                                      2.76629
# mean_score_time                                                   0.267403
# mean_test_score                                                    0.95671
# mean_train_score                                                   0.96168
# param_knn__n_neighbors                                                  17
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 17, 'svd__n_components': ...
# rank_test_score                                                          4
# split0_test_score                                                 0.948052
# split0_train_score                                                0.959459
# split1_test_score                                                 0.943723
# split1_train_score                                                0.965734
# split2_test_score                                                 0.965368
# split2_train_score                                                0.960907
# split3_test_score                                                 0.930736
# split3_train_score                                                0.965251
# split4_test_score                                                 0.978355
# split4_train_score                                                0.959942
# split5_test_score                                                 0.969697
# split5_train_score                                                0.962355
# split6_test_score                                                 0.943723
# split6_train_score                                                 0.96139
# split7_test_score                                                 0.952381
# split7_train_score                                                0.961873
# split8_test_score                                                 0.969697
# split8_train_score                                                0.957046
# split9_test_score                                                 0.965368
# split9_train_score                                                0.962838
# std_fit_time                                                     0.0405011
# std_score_time                                                   0.0218149
# std_test_score                                                   0.0143577
# std_train_score                                                 0.00247225
#
#                                                                         13  \
# mean_fit_time                                                      2.85069
# mean_score_time                                                   0.269085
# mean_test_score                                                    0.95671
# mean_train_score                                                  0.969836
# param_knn__n_neighbors                                                   5
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 5, 'svd__n_components': 5...
# rank_test_score                                                          4
# split0_test_score                                                 0.952381
# split0_train_score                                                 0.97056
# split1_test_score                                                 0.943723
# split1_train_score                                                0.971042
# split2_test_score                                                 0.974026
# split2_train_score                                                0.967181
# split3_test_score                                                 0.930736
# split3_train_score                                                0.973456
# split4_test_score                                                 0.982684
# split4_train_score                                                0.966699
# split5_test_score                                                  0.95671
# split5_train_score                                                0.972008
# split6_test_score                                                 0.952381
# split6_train_score                                                0.971525
# split7_test_score                                                 0.961039
# split7_train_score                                                0.972008
# split8_test_score                                                 0.961039
# split8_train_score                                                0.966216
# split9_test_score                                                 0.952381
# split9_train_score                                                0.967664
# std_fit_time                                                     0.0577749
# std_score_time                                                    0.023923
# std_test_score                                                   0.0138257
# std_train_score                                                 0.00249149
#
#                                                                         59  \
# mean_fit_time                                                      2.81146
# mean_score_time                                                   0.286674
# mean_test_score                                                   0.956277
# mean_train_score                                                  0.964044
# param_knn__n_neighbors                                                  15
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 15, 'svd__n_components': ...
# rank_test_score                                                          7
# split0_test_score                                                 0.952381
# split0_train_score                                                0.966699
# split1_test_score                                                 0.943723
# split1_train_score                                                0.966699
# split2_test_score                                                 0.978355
# split2_train_score                                                0.965251
# split3_test_score                                                 0.926407
# split3_train_score                                                0.964286
# split4_test_score                                                 0.974026
# split4_train_score                                                0.962838
# split5_test_score                                                 0.965368
# split5_train_score                                                0.963803
# split6_test_score                                                 0.935065
# split6_train_score                                                0.964286
# split7_test_score                                                  0.95671
# split7_train_score                                                0.963803
# split8_test_score                                                 0.969697
# split8_train_score                                                0.960425
# split9_test_score                                                 0.961039
# split9_train_score                                                0.962355
# std_fit_time                                                       0.36949
# std_score_time                                                   0.0439101
# std_test_score                                                   0.0161339
# std_train_score                                                 0.00182187
#
#                                                                         77  \
# mean_fit_time                                                       2.8022
# mean_score_time                                                   0.279998
# mean_test_score                                                   0.956277
# mean_train_score                                                  0.963562
# param_knn__n_neighbors                                                  19
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      3
# params                   {'knn__n_neighbors': 19, 'svd__n_components': ...
# rank_test_score                                                          7
# split0_test_score                                                  0.95671
# split0_train_score                                                 0.96332
# split1_test_score                                                 0.943723
# split1_train_score                                                0.964286
# split2_test_score                                                 0.974026
# split2_train_score                                                0.961873
# split3_test_score                                                 0.930736
# split3_train_score                                                0.968629
# split4_test_score                                                 0.978355
# split4_train_score                                                0.959459
# split5_test_score                                                 0.965368
# split5_train_score                                                0.964286
# split6_test_score                                                 0.939394
# split6_train_score                                                0.963803
# split7_test_score                                                 0.943723
# split7_train_score                                                0.965251
# split8_test_score                                                 0.969697
# split8_train_score                                                0.959942
# split9_test_score                                                 0.961039
# split9_train_score                                                0.964768
# std_fit_time                                                      0.152244
# std_score_time                                                   0.0264152
# std_test_score                                                   0.0152992
# std_train_score                                                 0.00252861
#
#                                                                         31  \
# mean_fit_time                                                      3.12071
# mean_score_time                                                   0.301301
# mean_test_score                                                   0.956277
# mean_train_score                                                  0.964817
# param_knn__n_neighbors                                                   9
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 9, 'svd__n_components': 5...
# rank_test_score                                                          7
# split0_test_score                                                 0.952381
# split0_train_score                                                0.964286
# split1_test_score                                                 0.943723
# split1_train_score                                                0.963803
# split2_test_score                                                 0.965368
# split2_train_score                                                 0.96139
# split3_test_score                                                 0.935065
# split3_train_score                                                0.969112
# split4_test_score                                                 0.974026
# split4_train_score                                                0.960425
# split5_test_score                                                 0.969697
# split5_train_score                                                0.965251
# split6_test_score                                                 0.939394
# split6_train_score                                                0.967181
# split7_test_score                                                  0.95671
# split7_train_score                                                0.967181
# split8_test_score                                                 0.965368
# split8_train_score                                                0.961873
# split9_test_score                                                 0.961039
# split9_train_score                                                0.967664
# std_fit_time                                                       0.14823
# std_score_time                                                   0.0470467
# std_test_score                                                   0.0126137
# std_train_score                                                 0.00280961
#
#                                                                         76  \
# mean_fit_time                                                      2.94009
# mean_score_time                                                   0.299834
# mean_test_score                                                   0.955844
# mean_train_score                                                  0.961873
# param_knn__n_neighbors                                                  19
# param_svd__n_components                                                 50
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 19, 'svd__n_components': ...
# rank_test_score                                                         10
# split0_test_score                                                 0.952381
# split0_train_score                                                0.962355
# split1_test_score                                                 0.943723
# split1_train_score                                                0.963803
# split2_test_score                                                 0.965368
# split2_train_score                                                 0.96139
# split3_test_score                                                 0.926407
# split3_train_score                                                0.964768
# split4_test_score                                                 0.978355
# split4_train_score                                                0.960425
# split5_test_score                                                 0.969697
# split5_train_score                                                 0.96332
# split6_test_score                                                 0.943723
# split6_train_score                                                0.960425
# split7_test_score                                                 0.943723
# split7_train_score                                                 0.96139
# split8_test_score                                                 0.969697
# split8_train_score                                                0.958012
# split9_test_score                                                 0.965368
# split9_train_score                                                0.962838
# std_fit_time                                                      0.155574
# std_score_time                                                   0.0701737
# std_test_score                                                   0.0154637
# std_train_score                                                  0.0018692
#
#                                                ...                          \
# mean_fit_time                                  ...
# mean_score_time                                ...
# mean_test_score                                ...
# mean_train_score                               ...
# param_knn__n_neighbors                         ...
# param_svd__n_components                        ...
# param_tfidf__min_df                            ...
# params                                         ...
# rank_test_score                                ...
# split0_test_score                              ...
# split0_train_score                             ...
# split1_test_score                              ...
# split1_train_score                             ...
# split2_test_score                              ...
# split2_train_score                             ...
# split3_test_score                              ...
# split3_train_score                             ...
# split4_test_score                              ...
# split4_train_score                             ...
# split5_test_score                              ...
# split5_train_score                             ...
# split6_test_score                              ...
# split6_train_score                             ...
# split7_test_score                              ...
# split7_train_score                             ...
# split8_test_score                              ...
# split8_train_score                             ...
# split9_test_score                              ...
# split9_train_score                             ...
# std_fit_time                                   ...
# std_score_time                                 ...
# std_test_score                                 ...
# std_train_score                                ...
#
#                                                                         61  \
# mean_fit_time                                                      3.58731
# mean_score_time                                                   0.348101
# mean_test_score                                                   0.938528
# mean_train_score                                                  0.954875
# param_knn__n_neighbors                                                  15
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 15, 'svd__n_components': ...
# rank_test_score                                                         72
# split0_test_score                                                 0.935065
# split0_train_score                                                0.954151
# split1_test_score                                                 0.917749
# split1_train_score                                                0.953185
# split2_test_score                                                 0.961039
# split2_train_score                                                0.956081
# split3_test_score                                                 0.904762
# split3_train_score                                                0.954633
# split4_test_score                                                 0.961039
# split4_train_score                                                0.955116
# split5_test_score                                                 0.952381
# split5_train_score                                                0.956564
# split6_test_score                                                 0.900433
# split6_train_score                                                0.951255
# split7_test_score                                                 0.939394
# split7_train_score                                                0.958977
# split8_test_score                                                  0.95671
# split8_train_score                                                0.951255
# split9_test_score                                                  0.95671
# split9_train_score                                                0.957529
# std_fit_time                                                     0.0848198
# std_score_time                                                   0.0379143
# std_test_score                                                   0.0221415
# std_train_score                                                 0.00240588
#
#                                                                         15  \
# mean_fit_time                                                      4.62902
# mean_score_time                                                   0.345567
# mean_test_score                                                   0.938095
# mean_train_score                                                  0.964141
# param_knn__n_neighbors                                                   5
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 5, 'svd__n_components': 1...
# rank_test_score                                                         73
# split0_test_score                                                 0.926407
# split0_train_score                                                0.966216
# split1_test_score                                                 0.930736
# split1_train_score                                                0.966699
# split2_test_score                                                 0.969697
# split2_train_score                                                0.964286
# split3_test_score                                                 0.926407
# split3_train_score                                                0.964768
# split4_test_score                                                 0.961039
# split4_train_score                                                 0.96332
# split5_test_score                                                 0.943723
# split5_train_score                                                0.958012
# split6_test_score                                                  0.91342
# split6_train_score                                                0.969112
# split7_test_score                                                 0.930736
# split7_train_score                                                0.962355
# split8_test_score                                                 0.935065
# split8_train_score                                                 0.96139
# split9_test_score                                                 0.943723
# split9_train_score                                                0.965251
# std_fit_time                                                       0.19085
# std_score_time                                                   0.0238143
# std_test_score                                                   0.0160874
# std_train_score                                                 0.00293609
#
#                                                                         42  \
# mean_fit_time                                                      4.71152
# mean_score_time                                                   0.360548
# mean_test_score                                                   0.937662
# mean_train_score                                                  0.954151
# param_knn__n_neighbors                                                  11
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 11, 'svd__n_components': ...
# rank_test_score                                                         74
# split0_test_score                                                 0.922078
# split0_train_score                                                0.956081
# split1_test_score                                                 0.948052
# split1_train_score                                                0.958494
# split2_test_score                                                 0.965368
# split2_train_score                                                0.954633
# split3_test_score                                                 0.926407
# split3_train_score                                                0.954151
# split4_test_score                                                 0.948052
# split4_train_score                                                0.946911
# split5_test_score                                                 0.952381
# split5_train_score                                                0.954151
# split6_test_score                                                 0.891775
# split6_train_score                                                0.955116
# split7_test_score                                                 0.917749
# split7_train_score                                                0.954633
# split8_test_score                                                 0.952381
# split8_train_score                                                0.954633
# split9_test_score                                                 0.952381
# split9_train_score                                                0.952703
# std_fit_time                                                      0.256917
# std_score_time                                                    0.033706
# std_test_score                                                   0.0212254
# std_train_score                                                 0.00280588
#
#                                                                         79  \
# mean_fit_time                                                      3.72803
# mean_score_time                                                   0.355088
# mean_test_score                                                   0.936797
# mean_train_score                                                  0.951062
# param_knn__n_neighbors                                                  19
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 19, 'svd__n_components': ...
# rank_test_score                                                         75
# split0_test_score                                                 0.926407
# split0_train_score                                                0.951737
# split1_test_score                                                 0.926407
# split1_train_score                                                0.951255
# split2_test_score                                                  0.95671
# split2_train_score                                                 0.95029
# split3_test_score                                                 0.891775
# split3_train_score                                                0.949324
# split4_test_score                                                 0.965368
# split4_train_score                                                0.950772
# split5_test_score                                                  0.95671
# split5_train_score                                                0.953668
# split6_test_score                                                 0.904762
# split6_train_score                                                0.946911
# split7_test_score                                                 0.939394
# split7_train_score                                                0.951255
# split8_test_score                                                 0.948052
# split8_train_score                                                0.948359
# split9_test_score                                                 0.952381
# split9_train_score                                                0.957046
# std_fit_time                                                      0.115813
# std_score_time                                                   0.0232155
# std_test_score                                                   0.0229233
# std_train_score                                                  0.0026715
#
#                                                                         51  \
# mean_fit_time                                                      4.67651
# mean_score_time                                                    0.35384
# mean_test_score                                                   0.934632
# mean_train_score                                                  0.952172
# param_knn__n_neighbors                                                  13
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 13, 'svd__n_components': ...
# rank_test_score                                                         76
# split0_test_score                                                 0.930736
# split0_train_score                                                0.953185
# split1_test_score                                                 0.943723
# split1_train_score                                                 0.95222
# split2_test_score                                                 0.952381
# split2_train_score                                                0.950772
# split3_test_score                                                 0.930736
# split3_train_score                                                0.955116
# split4_test_score                                                  0.95671
# split4_train_score                                                0.944981
# split5_test_score                                                 0.935065
# split5_train_score                                                0.954151
# split6_test_score                                                 0.896104
# split6_train_score                                                 0.95222
# split7_test_score                                                 0.909091
# split7_train_score                                                0.953668
# split8_test_score                                                 0.943723
# split8_train_score                                                0.952703
# split9_test_score                                                 0.948052
# split9_train_score                                                0.952703
# std_fit_time                                                      0.219847
# std_score_time                                                   0.0287798
# std_test_score                                                   0.0182076
# std_train_score                                                 0.00264741
#
#                                                                         60  \
# mean_fit_time                                                      4.65019
# mean_score_time                                                   0.347412
# mean_test_score                                                   0.934632
# mean_train_score                                                  0.949131
# param_knn__n_neighbors                                                  15
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 15, 'svd__n_components': ...
# rank_test_score                                                         76
# split0_test_score                                                 0.930736
# split0_train_score                                                0.949807
# split1_test_score                                                 0.939394
# split1_train_score                                                 0.95029
# split2_test_score                                                  0.95671
# split2_train_score                                                 0.95029
# split3_test_score                                                 0.922078
# split3_train_score                                                0.954633
# split4_test_score                                                 0.961039
# split4_train_score                                                0.945463
# split5_test_score                                                 0.939394
# split5_train_score                                                0.950772
# split6_test_score                                                 0.891775
# split6_train_score                                                 0.94305
# split7_test_score                                                  0.91342
# split7_train_score                                                0.948359
# split8_test_score                                                 0.943723
# split8_train_score                                                0.948842
# split9_test_score                                                 0.948052
# split9_train_score                                                0.949807
# std_fit_time                                                      0.201843
# std_score_time                                                   0.0226116
# std_test_score                                                   0.0198805
# std_train_score                                                 0.00296098
#
#                                                                         7   \
# mean_fit_time                                                      3.56747
# mean_score_time                                                   0.330755
# mean_test_score                                                   0.934632
# mean_train_score                                                  0.971622
# param_knn__n_neighbors                                                   3
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 3, 'svd__n_components': 1...
# rank_test_score                                                         76
# split0_test_score                                                 0.904762
# split0_train_score                                                0.971042
# split1_test_score                                                 0.930736
# split1_train_score                                                0.973938
# split2_test_score                                                  0.95671
# split2_train_score                                                0.972008
# split3_test_score                                                 0.900433
# split3_train_score                                                0.971525
# split4_test_score                                                  0.95671
# split4_train_score                                                0.972973
# split5_test_score                                                 0.930736
# split5_train_score                                                0.967664
# split6_test_score                                                 0.935065
# split6_train_score                                                0.973938
# split7_test_score                                                 0.952381
# split7_train_score                                                0.971525
# split8_test_score                                                 0.943723
# split8_train_score                                                0.968147
# split9_test_score                                                 0.935065
# split9_train_score                                                0.973456
# std_fit_time                                                     0.0675839
# std_score_time                                                   0.0245323
# std_test_score                                                   0.0186147
# std_train_score                                                  0.0021015
#
#                                                                         70  \
# mean_fit_time                                                        3.474
# mean_score_time                                                   0.330106
# mean_test_score                                                   0.933766
# mean_train_score                                                  0.952944
# param_knn__n_neighbors                                                  17
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      2
# params                   {'knn__n_neighbors': 17, 'svd__n_components': ...
# rank_test_score                                                         79
# split0_test_score                                                 0.917749
# split0_train_score                                                0.954633
# split1_test_score                                                 0.930736
# split1_train_score                                                0.949807
# split2_test_score                                                 0.952381
# split2_train_score                                                0.955116
# split3_test_score                                                 0.891775
# split3_train_score                                                0.948842
# split4_test_score                                                 0.961039
# split4_train_score                                                0.954633
# split5_test_score                                                 0.952381
# split5_train_score                                                0.955598
# split6_test_score                                                 0.904762
# split6_train_score                                                0.948842
# split7_test_score                                                 0.926407
# split7_train_score                                                0.954633
# split8_test_score                                                 0.948052
# split8_train_score                                                0.951255
# split9_test_score                                                 0.952381
# split9_train_score                                                0.956081
# std_fit_time                                                     0.0554556
# std_score_time                                                   0.0220602
# std_test_score                                                   0.0221626
# std_train_score                                                 0.00276616
#
#                                                                         69  \
# mean_fit_time                                                      4.54329
# mean_score_time                                                   0.345115
# mean_test_score                                                   0.932468
# mean_train_score                                                   0.94527
# param_knn__n_neighbors                                                  17
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 17, 'svd__n_components': ...
# rank_test_score                                                         80
# split0_test_score                                                 0.926407
# split0_train_score                                                0.949324
# split1_test_score                                                 0.930736
# split1_train_score                                                0.946911
# split2_test_score                                                 0.952381
# split2_train_score                                                0.944981
# split3_test_score                                                 0.926407
# split3_train_score                                                0.946429
# split4_test_score                                                  0.95671
# split4_train_score                                                 0.94305
# split5_test_score                                                 0.939394
# split5_train_score                                                0.947876
# split6_test_score                                                 0.896104
# split6_train_score                                                0.939189
# split7_test_score                                                  0.91342
# split7_train_score                                                0.944498
# split8_test_score                                                 0.939394
# split8_train_score                                                 0.94305
# split9_test_score                                                 0.943723
# split9_train_score                                                0.947394
# std_fit_time                                                      0.207363
# std_score_time                                                   0.0223312
# std_test_score                                                   0.0172292
# std_train_score                                                 0.00281582
#
#                                                                         78
# mean_fit_time                                                      4.80566
# mean_score_time                                                     0.3676
# mean_test_score                                                   0.924675
# mean_train_score                                                  0.942809
# param_knn__n_neighbors                                                  19
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 19, 'svd__n_components': ...
# rank_test_score                                                         81
# split0_test_score                                                 0.922078
# split0_train_score                                                0.947394
# split1_test_score                                                 0.930736
# split1_train_score                                                0.942568
# split2_test_score                                                 0.943723
# split2_train_score                                                0.944981
# split3_test_score                                                 0.922078
# split3_train_score                                                0.943533
# split4_test_score                                                 0.948052
# split4_train_score                                                0.940154
# split5_test_score                                                 0.926407
# split5_train_score                                                0.949324
# split6_test_score                                                 0.878788
# split6_train_score                                                0.936293
# split7_test_score                                                  0.91342
# split7_train_score                                                0.944015
# split8_test_score                                                 0.930736
# split8_train_score                                                0.940154
# split9_test_score                                                 0.930736
# split9_train_score                                                0.939672
# std_fit_time                                                       0.24329
# std_score_time                                                   0.0386373
# std_test_score                                                   0.0180785
# std_train_score                                                  0.0036961
#
# [33 rows x 81 columns]

# %%
gs_pipe.best_params_
# Out:
# {'knn__n_neighbors': 5, 'svd__n_components': 50, 'tfidf__min_df': 3}

# %%
plt.figure(figsize=(10,10))
plt.xticks(range(3,20,2),range(3,20,2))
plt.ylim([0.92,0.98])

for n_comp in params['svd__n_components']:
    plt.plot(gs_pipe_df['param_knn__n_neighbors'][gs_pipe_df['param_svd__n_components'] == n_comp], 
             gs_pipe_df['mean_train_score'][gs_pipe_df['param_svd__n_components'] == n_comp],
             '-^',label='n_components={}_train'.format(n_comp))
    plt.plot(gs_pipe_df['param_knn__n_neighbors'][gs_pipe_df['param_svd__n_components'] == n_comp], 
             gs_pipe_df['mean_test_score'][gs_pipe_df['param_svd__n_components'] == n_comp],
             '-o',label='n_components={}_test'.format(n_comp))
    plt.xlabel('n_neighbors')
    plt.ylabel('mean_score')
    plt.title('Mean train and test scores vs KNN n_neighbors for different SVD n_components')
    plt.legend()

# %%
sum(10*gs_pipe_df['mean_fit_time']+10*gs_pipe_df['mean_score_time'])/60
# Out:
# 45.478900416692099

# %% [markdown]
# ## Performing predictions on uncollected articles with the trained model

# %%
uncollected_articles_dict = pickle.loads(r.get('mlbi_uncollected_articles'))
lsa_vectorizer = pickle.loads(r.get('mlbi_vectorizer'))
fit_svd = pickle.loads(r.get('mlbi_fit_svd'))
knn_model = pickle.loads(r.get('mlbi_knn_model'))
pageid_title_df = pickle.loads(r.get('mlbi_pageid_title_df'))

new_article_ids = []
for val in uncollected_articles_dict.values():
    if len(val) != 0:
        for i in val:
            new_article_ids.append(i)

correct = []
false_pred_ids = {}
            
for artid in new_article_ids:
    article_text = wikipedia.page(pageid=artid).content
    predict_lsa = preprocess_search_text(article_text,lsa_vectorizer,fit_svd)
    title = pageid_title_df['title'][pageid_title_df['pageid'] == int(artid)].values[0]
    actual = pageid_title_df['category'][pageid_title_df['pageid'] == int(artid)].values[0]
    predicted = knn_model.predict(predict_lsa)[0]
    probabilities = knn_model.predict_proba(predict_lsa)
    max_probability = probabilities.max()
    correct.append([actual == predicted][0])
    if [actual == predicted][0] == False:
        false_pred_ids[artid] = [title,actual,predicted,max_probability]
    print("\nPage ID:", artid)
    print('Title:', title)
    print("Actual Category:", actual)
    print("Predicted Category:", predicted)
    print("Confidence Score:", round(max_probability,2))
    print("Correct prediction:", [actual == predicted][0])

print("\nTotal number of predictions:", len(correct))
print("Percent of correct predictions:", sum(correct)/len(correct))
# Out:
# Page ID: 52202762
# Title: Niki.ai
# Actual Category: Machine_learning
# Predicted Category: Business_intelligence
# Confidence Score: 1.0
# Correct prediction: False
#
# Page ID: 8220913
# Title: ADALINE
# Actual Category: Machine_learning
# Predicted Category: Machine_learning
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 4231161
# Title: ALOPEX
# Actual Category: Machine_learning
# Predicted Category: Machine_learning
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 32003319
# Title: (1+ε)-approximate nearest neighbor search
# Actual Category: Machine_learning
# Predicted Category: Machine_learning
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 41585002
# Title: MLPACK (C++ library)
# Actual Category: Machine_learning
# Predicted Category: Machine_learning
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 12481396
# Title: PROGNOZ
# Actual Category: Business_intelligence
# Predicted Category: Business_intelligence
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 33160128
# Title: INDEX
# Actual Category: Business_intelligence
# Predicted Category: Business_intelligence
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 4792160
# Title: VALS
# Actual Category: Business_intelligence
# Predicted Category: Business_intelligence
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 42371079
# Title: Healthcare Research & Analytics
# Actual Category: Business_intelligence
# Predicted Category: Business_intelligence
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 11893651
# Title: Challenger, Gray & Christmas
# Actual Category: Business_intelligence
# Predicted Category: Business_intelligence
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 2204878
# Title: Mason-Dixon Polling & Research Inc.
# Actual Category: Business_intelligence
# Predicted Category: Business_intelligence
# Confidence Score: 1.0
# Correct prediction: True
#
# Page ID: 4257833
# Title: Harris Insights & Analytics
# Actual Category: Business_intelligence
# Predicted Category: Business_intelligence
# Confidence Score: 0.8
# Correct prediction: True
#
# Page ID: 22045648
# Title: Siegel + Gale
# Actual Category: Business_intelligence
# Predicted Category: Business_intelligence
# Confidence Score: 1.0
# Correct prediction: True
#
# Total number of predictions: 13
# Percent of correct predictions: 0.9230769230769231

# %% [markdown]
# ## Performing searches on the same articles and comparing to the above predictions

# %%
for i in false_pred_ids.keys():
    search_article_text = wikipedia.page(pageid=i).content

    vectorizer, fitted_svd, lsa = fit_svd_for_lsa(article_contents_df['clean_text'])

    search_lsa = preprocess_search_text(search_article_text,vectorizer,fitted_svd)

    top_five, top_text = five_most_similar_docs(lsa,search_lsa,article_contents_df)

    print("\n\nSearch text:\n")
    print("Title:", false_pred_ids[i][0])
    print("Actual Category:", false_pred_ids[i][1])
    print("Predicted Category:", false_pred_ids[i][2])
    print("Confidence Score:", false_pred_ids[i][3])
    print("Introduction:", search_article_text.split('\n',1)[0])

    print("\n")
    print("The top 5 related articles are the following:\n")
    print(top_five[['category','title']],"\n\n")

    print("The text from the top related article is below:\n")
    print("Title:", top_text[['title']][0],"\n")
    print("Category:", top_text[['category']][0],"\n")
    print("Website: https://en.wikipedia.org/wiki/{}".format(re.sub('\s','_',top_text[['title']][0])),"\n")
    print("Introduction:", top_text[['clean_text']][0].split('\n',1)[0])
# Out:
# Search text:
#
# Title: Niki.ai
# Actual Category: Machine_learning
# Predicted Category: Business_intelligence
# Confidence Score: 1.0
# Introduction: Niki is an Indian online electronic commerce company headquartered in Bangalore, Karnataka. It was founded in May 2015 by 4 IIT Kharagpur graduates - Sachin Jaiswal, Keshav Prawasi, Shishir Modi and Nitin Babel.
#
#
# The top 5 related articles are the following:
#
#                    category           title
# 1140  Business_intelligence  Flok (company)
# 1947  Business_intelligence            Kiip
# 148        Machine_learning            Qloo
# 1970  Business_intelligence         Sinemia
# 1822  Business_intelligence      SimilarWeb
#
#
# The text from the top related article is below:
#
# Title: Flok (company)
#
# Category: Business_intelligence
#
# Website: https://en.wikipedia.org/wiki/Flok_(company)
#
# Introduction: flok (formerly Loyalblocks) is an American tech startup based in New York City that provides marketing solutions such as chatbots/AI, customer loyalty programs, mobile apps and CRM services to local businesses.

# %%
gs_pipe_df[gs_pipe_df['param_tfidf__min_df'] == 1][gs_pipe_df['param_svd__n_components'] == 100].sort_values('rank_test_score').T
# Out:
#                                                                         24  \
# mean_fit_time                                                      4.64638
# mean_score_time                                                   0.352874
# mean_test_score                                                   0.942424
# mean_train_score                                                  0.961197
# param_knn__n_neighbors                                                   7
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 7, 'svd__n_components': 1...
# rank_test_score                                                         63
# split0_test_score                                                 0.926407
# split0_train_score                                                0.962838
# split1_test_score                                                 0.948052
# split1_train_score                                                0.965251
# split2_test_score                                                 0.969697
# split2_train_score                                                0.958012
# split3_test_score                                                 0.917749
# split3_train_score                                                0.962838
# split4_test_score                                                 0.965368
# split4_train_score                                                0.957046
# split5_test_score                                                 0.952381
# split5_train_score                                                0.963803
# split6_test_score                                                 0.904762
# split6_train_score                                                0.958977
# split7_test_score                                                 0.935065
# split7_train_score                                                 0.96332
# split8_test_score                                                  0.95671
# split8_train_score                                                0.959942
# split9_test_score                                                 0.948052
# split9_train_score                                                0.959942
# std_fit_time                                                      0.277156
# std_score_time                                                   0.0360888
# std_test_score                                                   0.0199369
# std_train_score                                                 0.00261866
#
#                                                                         33  \
# mean_fit_time                                                      4.88196
# mean_score_time                                                   0.376364
# mean_test_score                                                   0.942424
# mean_train_score                                                   0.95584
# param_knn__n_neighbors                                                   9
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 9, 'svd__n_components': 1...
# rank_test_score                                                         63
# split0_test_score                                                 0.926407
# split0_train_score                                                0.957046
# split1_test_score                                                 0.943723
# split1_train_score                                                0.959459
# split2_test_score                                                 0.978355
# split2_train_score                                                0.956081
# split3_test_score                                                 0.930736
# split3_train_score                                                0.958012
# split4_test_score                                                 0.965368
# split4_train_score                                                 0.95029
# split5_test_score                                                  0.95671
# split5_train_score                                                0.956564
# split6_test_score                                                 0.891775
# split6_train_score                                                0.955598
# split7_test_score                                                 0.926407
# split7_train_score                                                0.955598
# split8_test_score                                                  0.95671
# split8_train_score                                                0.955116
# split9_test_score                                                 0.948052
# split9_train_score                                                0.954633
# std_fit_time                                                      0.199978
# std_score_time                                                   0.0310973
# std_test_score                                                   0.0233967
# std_train_score                                                 0.00229691
#
#                                                                         6   \
# mean_fit_time                                                       4.6397
# mean_score_time                                                   0.345122
# mean_test_score                                                    0.94026
# mean_train_score                                                  0.972876
# param_knn__n_neighbors                                                   3
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 3, 'svd__n_components': 1...
# rank_test_score                                                         69
# split0_test_score                                                 0.939394
# split0_train_score                                                 0.97249
# split1_test_score                                                 0.930736
# split1_train_score                                                0.972973
# split2_test_score                                                 0.965368
# split2_train_score                                                0.970077
# split3_test_score                                                 0.922078
# split3_train_score                                                0.974421
# split4_test_score                                                 0.965368
# split4_train_score                                                0.973456
# split5_test_score                                                 0.943723
# split5_train_score                                                0.969595
# split6_test_score                                                 0.917749
# split6_train_score                                                0.975869
# split7_test_score                                                 0.939394
# split7_train_score                                                0.973938
# split8_test_score                                                 0.939394
# split8_train_score                                                0.971525
# split9_test_score                                                 0.939394
# split9_train_score                                                0.974421
# std_fit_time                                                      0.195259
# std_score_time                                                   0.0291495
# std_test_score                                                   0.0148454
# std_train_score                                                  0.0018915
#
#                                                                         15  \
# mean_fit_time                                                      4.62902
# mean_score_time                                                   0.345567
# mean_test_score                                                   0.938095
# mean_train_score                                                  0.964141
# param_knn__n_neighbors                                                   5
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 5, 'svd__n_components': 1...
# rank_test_score                                                         73
# split0_test_score                                                 0.926407
# split0_train_score                                                0.966216
# split1_test_score                                                 0.930736
# split1_train_score                                                0.966699
# split2_test_score                                                 0.969697
# split2_train_score                                                0.964286
# split3_test_score                                                 0.926407
# split3_train_score                                                0.964768
# split4_test_score                                                 0.961039
# split4_train_score                                                 0.96332
# split5_test_score                                                 0.943723
# split5_train_score                                                0.958012
# split6_test_score                                                  0.91342
# split6_train_score                                                0.969112
# split7_test_score                                                 0.930736
# split7_train_score                                                0.962355
# split8_test_score                                                 0.935065
# split8_train_score                                                 0.96139
# split9_test_score                                                 0.943723
# split9_train_score                                                0.965251
# std_fit_time                                                       0.19085
# std_score_time                                                   0.0238143
# std_test_score                                                   0.0160874
# std_train_score                                                 0.00293609
#
#                                                                         42  \
# mean_fit_time                                                      4.71152
# mean_score_time                                                   0.360548
# mean_test_score                                                   0.937662
# mean_train_score                                                  0.954151
# param_knn__n_neighbors                                                  11
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 11, 'svd__n_components': ...
# rank_test_score                                                         74
# split0_test_score                                                 0.922078
# split0_train_score                                                0.956081
# split1_test_score                                                 0.948052
# split1_train_score                                                0.958494
# split2_test_score                                                 0.965368
# split2_train_score                                                0.954633
# split3_test_score                                                 0.926407
# split3_train_score                                                0.954151
# split4_test_score                                                 0.948052
# split4_train_score                                                0.946911
# split5_test_score                                                 0.952381
# split5_train_score                                                0.954151
# split6_test_score                                                 0.891775
# split6_train_score                                                0.955116
# split7_test_score                                                 0.917749
# split7_train_score                                                0.954633
# split8_test_score                                                 0.952381
# split8_train_score                                                0.954633
# split9_test_score                                                 0.952381
# split9_train_score                                                0.952703
# std_fit_time                                                      0.256917
# std_score_time                                                    0.033706
# std_test_score                                                   0.0212254
# std_train_score                                                 0.00280588
#
#                                                                         51  \
# mean_fit_time                                                      4.67651
# mean_score_time                                                    0.35384
# mean_test_score                                                   0.934632
# mean_train_score                                                  0.952172
# param_knn__n_neighbors                                                  13
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 13, 'svd__n_components': ...
# rank_test_score                                                         76
# split0_test_score                                                 0.930736
# split0_train_score                                                0.953185
# split1_test_score                                                 0.943723
# split1_train_score                                                 0.95222
# split2_test_score                                                 0.952381
# split2_train_score                                                0.950772
# split3_test_score                                                 0.930736
# split3_train_score                                                0.955116
# split4_test_score                                                  0.95671
# split4_train_score                                                0.944981
# split5_test_score                                                 0.935065
# split5_train_score                                                0.954151
# split6_test_score                                                 0.896104
# split6_train_score                                                 0.95222
# split7_test_score                                                 0.909091
# split7_train_score                                                0.953668
# split8_test_score                                                 0.943723
# split8_train_score                                                0.952703
# split9_test_score                                                 0.948052
# split9_train_score                                                0.952703
# std_fit_time                                                      0.219847
# std_score_time                                                   0.0287798
# std_test_score                                                   0.0182076
# std_train_score                                                 0.00264741
#
#                                                                         60  \
# mean_fit_time                                                      4.65019
# mean_score_time                                                   0.347412
# mean_test_score                                                   0.934632
# mean_train_score                                                  0.949131
# param_knn__n_neighbors                                                  15
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 15, 'svd__n_components': ...
# rank_test_score                                                         76
# split0_test_score                                                 0.930736
# split0_train_score                                                0.949807
# split1_test_score                                                 0.939394
# split1_train_score                                                 0.95029
# split2_test_score                                                  0.95671
# split2_train_score                                                 0.95029
# split3_test_score                                                 0.922078
# split3_train_score                                                0.954633
# split4_test_score                                                 0.961039
# split4_train_score                                                0.945463
# split5_test_score                                                 0.939394
# split5_train_score                                                0.950772
# split6_test_score                                                 0.891775
# split6_train_score                                                 0.94305
# split7_test_score                                                  0.91342
# split7_train_score                                                0.948359
# split8_test_score                                                 0.943723
# split8_train_score                                                0.948842
# split9_test_score                                                 0.948052
# split9_train_score                                                0.949807
# std_fit_time                                                      0.201843
# std_score_time                                                   0.0226116
# std_test_score                                                   0.0198805
# std_train_score                                                 0.00296098
#
#                                                                         69  \
# mean_fit_time                                                      4.54329
# mean_score_time                                                   0.345115
# mean_test_score                                                   0.932468
# mean_train_score                                                   0.94527
# param_knn__n_neighbors                                                  17
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 17, 'svd__n_components': ...
# rank_test_score                                                         80
# split0_test_score                                                 0.926407
# split0_train_score                                                0.949324
# split1_test_score                                                 0.930736
# split1_train_score                                                0.946911
# split2_test_score                                                 0.952381
# split2_train_score                                                0.944981
# split3_test_score                                                 0.926407
# split3_train_score                                                0.946429
# split4_test_score                                                  0.95671
# split4_train_score                                                 0.94305
# split5_test_score                                                 0.939394
# split5_train_score                                                0.947876
# split6_test_score                                                 0.896104
# split6_train_score                                                0.939189
# split7_test_score                                                  0.91342
# split7_train_score                                                0.944498
# split8_test_score                                                 0.939394
# split8_train_score                                                 0.94305
# split9_test_score                                                 0.943723
# split9_train_score                                                0.947394
# std_fit_time                                                      0.207363
# std_score_time                                                   0.0223312
# std_test_score                                                   0.0172292
# std_train_score                                                 0.00281582
#
#                                                                         78
# mean_fit_time                                                      4.80566
# mean_score_time                                                     0.3676
# mean_test_score                                                   0.924675
# mean_train_score                                                  0.942809
# param_knn__n_neighbors                                                  19
# param_svd__n_components                                                100
# param_tfidf__min_df                                                      1
# params                   {'knn__n_neighbors': 19, 'svd__n_components': ...
# rank_test_score                                                         81
# split0_test_score                                                 0.922078
# split0_train_score                                                0.947394
# split1_test_score                                                 0.930736
# split1_train_score                                                0.942568
# split2_test_score                                                 0.943723
# split2_train_score                                                0.944981
# split3_test_score                                                 0.922078
# split3_train_score                                                0.943533
# split4_test_score                                                 0.948052
# split4_train_score                                                0.940154
# split5_test_score                                                 0.926407
# split5_train_score                                                0.949324
# split6_test_score                                                 0.878788
# split6_train_score                                                0.936293
# split7_test_score                                                  0.91342
# split7_train_score                                                0.944015
# split8_test_score                                                 0.930736
# split8_train_score                                                0.940154
# split9_test_score                                                 0.930736
# split9_train_score                                                0.939672
# std_fit_time                                                       0.24329
# std_score_time                                                   0.0386373
# std_test_score                                                   0.0180785
# std_train_score                                                  0.0036961
